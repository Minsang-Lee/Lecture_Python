# %% [markdown]
# # 텍스트 마이닝 3 - 자연어 텍스트 처리 (NLTK & KoNLPy)
#
# <div align='center'><img src='attachment:6589aa25-9c02-4176-ac63-bed875bc659d.png'></div>

# %% [markdown]
# ### 코랩: 한글 폰트 설치

# %% [markdown]
# 1.한글 폰트 설치

# %%
#폰트 설치
! apt install fonts-nanum*

# %%
! apt install fontconfig

# %% [markdown]
# 2. 폰트 캐시 생성

# %%
#폰트 캐시 생성
# !fc-cache -fv

# %% [markdown]
# 3. matplotlib에 남아있는 font 캐시 삭제

# %%
# matplotlib에 남아있는 font 캐시 삭제
# !rm -rf ~/.cache/matplotlib/*

# %% [markdown]
# 4. Runtime 재실행

# %%
import matplotlib.font_manager as fm
# 폰트 목록에서 폰트 찾기
for font in fm.fontManager.ttflist:
    if 'Nanum' in font.name:
        print(font.name, font.fname)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (14,4)

# font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
font_path = '/Users/qkboo/Library/Fonts/NanumGothic.otf'
fontname = fm.FontProperties(fname=font_path, size=18).get_name()  # 폰트 패밀리 이름!

# matplotlib 한글 출력 확인용 테스트
plt.rcParams["font.family"] = fontname
plt.rcParams['axes.unicode_minus'] = False
plt.title('한글 테스트')

# %% [markdown]
# # NLTK
#
# NLTK(Natural Language Toolkit): 자연어 처리 및 문서 분석용 패키지
# 1. 말뭉치
# 2. 토큰 생성
# 3. 형태소 분석
# 4. 품사 태깅

# %% [markdown]
# NLTK 설치

# %%
! pip install nltk

# %% [markdown]
# ## 1. NLTK 코퍼스 (nltk.corpus 모듈)
# http://www.nltk.org/nltk_data/ (전체목록)
#
# 주요 코퍼스
# * gutenberg : 모비딕(Moby Dick), 성서등 구텐베르크 프로젝트 영문 책 텍스트 18개
# * reuters: 10,788 뉴스 문서, 천3백만 단어, 90개 토픽, "training" 과 "test"로 나누어져 있다.
# * brown : 브라운대(1961) 최초 백만단어 코퍼스, 뉴스 학습자료등 카테고리가 나누어져 있다
# * names : 8,000개의 남성과 여성의 이름
# * words : 가장 빈번하게 사용하는 영어 단어 23,5000개
# * stopwords : 14개의 언어의 가장 많이 사용하는 불용어(stop word)
# * cmudict : 카네기멜론대, 13,4000개 단어와 그 음절(syllables)로 구성. 동음이의어(homophones) 검색.

# %%
import nltk

nltk.download("gutenberg")
nltk.download("reuters")
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

# %%
# 제공되는 텍스트 문서 확인
import nltk
fileids = nltk.corpus.gutenberg.fileids()
print(fileids)

# %% [markdown]
# * corpus.fileids() # 코퍼스에 포함된 파일아이디 목록
# * corpus.raw(fileid) # 파일의 원문
# * corpus.sents(fileid) #파일의 문장 목록
# * corpus.words(fileid) # 파일의 단어 목록

# %%
from nltk.corpus import gutenberg

for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid)) # 문자수
    num_words = len(gutenberg.words(fileid)) # 단어수
    num_sents = len(gutenberg.sents(fileid)) # 문장수
    num_vocab = len(set(w.lower() for w in gutenberg.words(fileid))) # 어휘수
    print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)

# %% [markdown]
# ### 말뭉치 문서 읽기

# %%
import nltk
from nltk.corpus import gutenberg

# %%
nltk.corpus.gutenberg.fileids()

# %%
# 1. read document
moby_dick_text = gutenberg.open('melville-moby_dick.txt').read()
moby_dick_text[:1000]

# %% [markdown]
# ## 2. 토큰 생성 Toknize
#
# 텍스트를 처리하기 위한 작은 단위(token)으로 나눈다. NLTK는 다음 토큰 생성을 제공
#
# ```python
# from nltk.tokenize import sent_tokenize # 문장으로 나누기
# from nltk.tokenize import word_tokenize # 단어로 나누기
# from nltk.tokenize import regexp_tokenize # 정규식으로 나누기
# ```

# %%
from nltk.tokenize import sent_tokenize

moby_sents = sent_tokenize(moby_dick_text)
moby_sents[100:110]

# %%
from nltk.tokenize import word_tokenize

moby_words = word_tokenize(moby_dick_text)
moby_words[100:110]

# %%
len(moby_words)

# %%
from nltk import regexp_tokenize

moby_retoks = regexp_tokenize(moby_dick_text.lower(), r"[\w]+")
moby_retoks[100:110]

# %%
len(moby_retoks)

# %% [markdown]
# ## 3. 형태소 분석
#
# nltk.Text 클래스를 사용해서 형태소를 분석할 수 있다.
#
# 참고 http://www.nltk.org/api/nltk.html#nltk.text.Text

# %%
import nltk
moby = nltk.Text(moby_retoks)

# %%
print(len(moby.tokens)) # 토큰 개수
print(len(set(moby.tokens))) # 고유한 토큰 개수

# %% [markdown]
# ### 빈도 분포 FreqDist

# %%
freq_dist = moby.vocab() # FreqDist (빈도 분포)
print(len(freq_dist))

# %%
print(freq_dist.most_common(50)) # 가장 많이 등장하는 50개

# %%
moby.plot(50)

# %%
freq_dist.plot(50)

# %% [markdown]
# ### count

# %%
moby.count('captain')

# %% [markdown]
# ### Dispersion plot
# 단어가 등장하는 위치를 Word Offset에 따라 배치하여 시각화
#
# 모비딕의 주요 등장인물들: 'ahab', 'starbuck', 'queequeg', 'ishmael', 'stubb', 'flask', 'fedallah'

# %%
moby.dispersion_plot(['ahab', 'starbuck', 'queequeg', 'ishmael', 'stubb', 'flask', 'fedallah'])

# %% [markdown]
# ### Concordance
#
# Concordance (색인): 단어가 쓰인 문맥을 모두 찾아준다

# %%
moby.concordance('ahab', lines=10)

# %% [markdown]
# ### Similar word
#
# 주어진 단어와 비슷한 환경(same context)에서 쓰인(≠비슷한 뜻) 단어들

# %%
moby.similar('whale')

# %%
moby.similar('ship')

# %%
moby.similar('god')

# %% [markdown]
# ### common_contexts
#
# for two words used in similar contexts

# %%
moby.common_contexts(['monstrous', 'true'])

# %% [markdown]
# ### Collocations
# 연어(連語, collocation): 함께 위치하는 단어들 (co + location), 어휘의 조합 또는 짝을 이루는 단어

# %%
moby.collocations()

# %% [markdown]
# ## 4. 품사 태깅 PoS Tagging
# NLTK 에서는 Penn Treebank Tagset 을 이용
#
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
#
# 예를 들어,
# * NN: 일반명사 단수
# * NNS: 일반명사 복수
# * NNP: 대명사 단수
# * NNPS: 대명사 복수

# %%
# 간단한 예제

nltk.pos_tag(['The', 'earth', 'is', 'a', 'beautiful', 'planet'])

# %% [markdown]
# * DT: 한정사
# * NN: 명사, 단수형
# * VBZ: 동사, 현재형 시제, 3인칭 단수
# * JJ: 형용사

# %%
# 허먼 멜빌, "모비딕" 첫 단락
# 나를 이스마엘로 불러라. 몇 년 전, 정확히 얼마나 오래 동안 그랬는지는 모르겠지만, 
# 내 지갑에 돈 한 푼 없는 빈털터리 신세에 육상에선 특별히 흥미를 끄는 어떤 것도 없던 그런 시절, 
# 나는 잠시 동안이나마 배를 타고 세계의 바다를 보고 싶다는 생각을 했다. 
# 그것이 우울하고 의기소침한 감정, 그 반복되는 악순환의 고리를 끊어버리는 한 방법이었다.

moby_dick_first_para_text = '''
Call me Ishmael.  Some years ago -- never mind how long
precisely--having little or no money in my purse, and nothing
particular to interest me on shore, I thought I would sail about a
little and see the watery part of the world. 
It is a way I have of driving off the spleen, and regulating the circulation. 
'''

import nltk
from nltk.tokenize import word_tokenize

moby_words = word_tokenize(moby_dick_first_para_text)
tasg = nltk.pos_tag(moby_words)
tasg[:20]

# %% [markdown]
# ## Noun phrase chunking
#
#
# ```python
# # Colab 에서는 출력되지 않습니다.
#
# text = 'The earth is a beautiful planet.'
#
# tokens = text.split()
# tags = nltk.pos_tag(tokens)
# parser = nltk.RegexpParser("NP: {<DT>?<JJ>?<NN.*>*}")
# tree = parser.parse(tags)
# tree
# ```
#
# <img src="https://i.imgur.com/zhwGPri.png">

# %% [markdown]
# ## Stemming (어간 추출), lemmatizing (표제어 추출)
#
# NLTK 지원
# * Stemmer: Porter(보수적), Lancaster(적극적)
# * Lemmatizer: WordNetLemmatizer (WordNet 이 계산한 형태소를 참조, 인터넷 연결 필요)
#
# Stemmer vs Lemmatizer
# * stemming은 단어만 본다 (결과 stem이 사전에 없을 수도 있다)
# * Lemmatizer는 더 느리고 더 보수적

# %%
p_stmr = nltk.PorterStemmer()
p_stmr.stem("wonderful"), p_stmr.stem("flying"), p_stmr.stem("flies")

# %%
l_stmr = nltk.LancasterStemmer()
l_stmr.stem("wonderful"), l_stmr.stem("flying"), l_stmr.stem("flies")

# %%
lmtz = nltk.WordNetLemmatizer()
lmtz.lemmatize("wonderful"), lmtz.lemmatize("flying"), lmtz.lemmatize("flies")

# %%
# POS: # n=명사, v=동사, a=형용사, r=부사
print(lmtz.lemmatize("cats"))
print(lmtz.lemmatize("better", pos="a")) 
print(lmtz.lemmatize("is", pos="v"))
print(lmtz.lemmatize("led"))
print(lmtz.lemmatize("led",'v'))

# %% [markdown]
# ---
#
# ## 요약
#
# * NLTK 코퍼스
# * Concordance (색인)
# * Similar Word: Similar context 단어들 (≠비슷한 뜻)
# * common_contexts
# * Collocations (연어)
# * PoS Tagging
# * chunking
# * Stemming (어간 추출), lemmatizing (표제어 추출)

# %% [markdown]
# >

# %% [markdown]
# #  한국어 텍스트 처리 (KoNLPy)
#
# ![image.png](https://i.imgur.com/xUnCy2i.png)
#
#
#  - http://konlpy.org/ko
#
# 국어 정보처리를 위한 파이썬 패키지 ('코엔엘파이'라고 읽는다). 한국어 말뭉치와 형태소 분석기를 제공한다.
#
# * 한국어 말뭉치
# * 형태소 분석 및 품사 태깅

# %% [markdown]
# ## KoNLPy 개발환경
#
# https://konlpy.org/ko/latest/install/
#
# 1. JDK 설치 필요
# 2. KoNLPy 설치

# %% [markdown]
# ###  JDK 설치 필요
#
# - https://www.oracle.com/java/technologies/downloads/
#
# 1. 자바(JVM)설치 필요Permalink
# 1. 설치 후 JAVA_HOME 및 Path 설정 필요
#
# ![image.png](attachment:471dcadc-756f-4bc8-9079-062928e20521.png)

# %% [markdown]
# #### 우분투
#
# Install Java 1.8 or up
#
# ```
# sudo apt-get install g++ openjdk-8-jdk curl
# ```

# %%
! java --version
# Out:
# Unrecognized option: --version
# Error: Could not create the Java Virtual Machine.
# Error: A fatal exception has occurred. Program will exit.

# %%
! python -V
# Out:
# Python 3.9.13

# %% [markdown]
# ## 2. KoNLPy 설치

# %% [markdown]
# ### - Python3.9, 2022/07
#
# Python 3.8, 3.9

# %% [markdown]
# Python3.9 에서 설치된 버전
#  - JPype1-1.4.0
#  - konlpy-0.6.0
#  - nltk 3.7
#  - numpy==1.22.4

# %%
! pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      --------------------------------------- 19.4/19.4 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6 in c:\users\sbauser\.venv\second_day\lib\site-packages (from konlpy) (1.23.4)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\sbauser\.venv\second_day\lib\site-packages (from konlpy) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp39-cp39-win_amd64.whl (345 kB)
#      ------------------------------------- 345.2/345.2 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\sbauser\.venv\second_day\lib\site-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sbauser\.venv\second_day\lib\site-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %% [markdown]
# ## 1. 한국어 말뭉치 지원
# * kolaw: 한국 법률 말뭉치 (constitution.txt)
# * kobill: 대한민국 국회 의안 말뭉치 (1809890.txt ~ 1809899.txt)

# %%
from konlpy.corpus import kolaw
kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
c = kolaw.open('constitution.txt').read()
print(c[:500])
# Out:
# 대한민국헌법
#
# 유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제·사회·문화의 모든 영역에 있어서 각인의 기회를 균등히 하고, 능력을 최고도로 발휘하게 하며, 자유와 권리에 따르는 책임과 의무를 완수하게 하여, 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 1948년 7월 12일에 제정되고 8차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다.
#
#        제1장 총강
#   제1조 ① 대한민국은 민주공화국이다.
# ②대한민국의 주권은 국민에게 있고,

# %%
from konlpy.corpus import kobill
print(kobill.fileids())
# Out:
# ['1809890.txt', '1809891.txt', '1809892.txt', '1809893.txt', '1809894.txt', '1809895.txt', '1809896.txt', '1809897.txt', '1809898.txt', '1809899.txt']

# %%
doc_ko = kobill.open('1809897.txt').read()
print(doc_ko[:100])
# Out:
# 국군부대의 아랍에미리트(UAE)군 교육훈련 지원 등에
# 관한 파견 동의안
#
# 의안

# %% [markdown]
# ### 말뭉치 정리
#
# 1. https://corpus.korean.go.kr/
# 1. https://ilis.yonsei.ac.kr/corpus/#/
# 1. https://zetawiki.com/wiki/%ED%95%9C%EA%B5%AD%EC%96%B4_%EB%A7%90%EB%AD%89%EC%B9%98_%EB%AA%A8%EC%9D%8C

# %% [markdown]
# ## 2. 형태소 분석 및 품사 태깅
#
#
# 한국어 형태소 분석기 프로젝트
#
# http://konlpy-ko.readthedocs.io
#
# 프로젝트 | 이름 | 홈페이지
# :---- | :---- | :----
# 한나눔 | Hannanum | http://kldp.net/hannanum/
# 꼬꼬마 | Kkma | http://kkma.snu.ac.kr/
# 코모란 | Komoran | http://www.shineware.co.kr/products/komoran/
# 은전한닢 | Mecab | https://bitbucket.org/eunjeon/mecab-ko/
# 트위터 | Okt | https://github.com/open-korean-text/open-korean-text
#
# 비교 http://konlpy.org/en/v0.4.4/morph/

# %% [markdown]
# 각 클래스의 주요 메소드
# * morphs : 형태소 추출
# * nouns : 명사 추출
# * pos : pos 태깅

# %% [markdown]
# ### 한글 Token 생성
#
# 일정한 뜻을 가진 가장 작은 말의 단위로 토큰화 한다. 문장에서 단어를 검색해서 토큰을 추출한다. 토큰은 문장(sentence) 단위, 단어(word) 단위로 토큰화한다.
#
#  - from nltk.tokenize import sent_tokenize # 문장으로 나누기
# - from nltk.tokenize import word_tokenize # 단어로 나누기
# - from nltk.tokenize import regexp_tokenize # 정규식으로 나누기
# - 한글 형태소 분석기
#    - `konlp.tag.[분석기].morphs()`
#    - `konlp.tag.[분석기].nouns()`

# %%
doc_ko = kobill.open('1809897.txt').read()
print(doc_ko[:100])
# Out:
# 국군부대의 아랍에미리트(UAE)군 교육훈련 지원 등에
# 관한 파견 동의안
#
# 의안

# %%
type(doc_ko)
# Out:
# str

# %%
doc_ko.split('  ')[:20] #space two
# Out:
# ['국군부대의 아랍에미리트(UAE)군 교육훈련 지원 등에 \n관한 파견 동의안\n\n의안\n',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
import nltk

tokens_ko = nltk.regexp_tokenize(doc_ko, r'(\w+)')
tokens_ko
# Out:
# ['국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '의안',
#  '제출연월일',
#  '2010',
#  '11',
#  '15',
#  '9897',
#  '번호',
#  '제',
#  '출',
#  '자',
#  '정',
#  '부',
#  '제안이유',
#  '가',
#  'UAE측',
#  '요청과',
#  '협의에',
#  '따라',
#  '국익창출과',
#  '다양한',
#  '지역에서의',
#  '우리',
#  '특전부대',
#  '임무수행능력',
#  '향상',
#  '등을',
#  '목적으로',
#  '국군부대를',
#  'UAE에',
#  '파견하려는',
#  '것임',
#  '나',
#  '국군부대',
#  '파견을',
#  '계기로',
#  '우리',
#  '특전부대의',
#  '전투력',
#  '향상은',
#  '물론',
#  'UAE에',
#  '대한',
#  '방산수출협력',
#  '확대',
#  '국방운영체계',
#  '수출',
#  '예비역',
#  '및',
#  '민간',
#  '전문인력',
#  '진출',
#  '양국간',
#  '경제협력',
#  '확대',
#  '등이',
#  '기대됨',
#  '주요내용',
#  '가',
#  '국군부대의',
#  '임무는',
#  'UAE군',
#  '특수전',
#  '부대에',
#  '대한',
#  '교육훈련',
#  '지원',
#  'UAE군',
#  '특수전',
#  '부대와',
#  '연합훈련',
#  '및',
#  '연습',
#  '유사시',
#  '우리',
#  '국민',
#  '보호임',
#  '나',
#  '파견규모는',
#  '150명',
#  '이내이며',
#  '파견지역은',
#  'UAE',
#  '아부다비주',
#  '알아인',
#  '소재',
#  '특수전학교임',
#  '다',
#  '파견기간은',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지임',
#  '라',
#  '부대',
#  '지휘권은',
#  '한국군이',
#  '보유하며',
#  '우리',
#  '합동참모의장이',
#  '작전지휘함',
#  '마',
#  '국군부대의',
#  '파견경비는',
#  '우리',
#  '정부의',
#  '부담으로',
#  '함',
#  '참고사항',
#  '가',
#  '관련법령',
#  '헌법',
#  '제60조',
#  '제2항',
#  '나',
#  '예산조치',
#  '국회',
#  '동의',
#  '후',
#  '2011년도',
#  '예산안에',
#  '대한',
#  '국회',
#  '심의과정',
#  '에서',
#  '반영',
#  '추진',
#  '다',
#  '합',
#  '의',
#  '외교통상부',
#  '기획재정부와',
#  '합의되었음',
#  '1',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  'UAE군',
#  '교육훈련',
#  '지원',
#  '등을',
#  '위해',
#  '150명',
#  '이내의',
#  '국군부대를',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '2년간',
#  'UAE에',
#  '파견하는',
#  '것을',
#  '헌법',
#  '제60조',
#  '제2항의',
#  '규정에',
#  '따라',
#  '동의한다',
#  '3',
#  '1',
#  '국군부대',
#  '파견',
#  '목적',
#  '및',
#  '경과',
#  '가',
#  '파견목적',
#  'UAE측',
#  '요청과',
#  '협의에',
#  '따라',
#  '국익창출과',
#  '다양한',
#  '지역에서의',
#  '우리',
#  '특전부대',
#  '임무수행능력',
#  '향상',
#  '등을',
#  '목적으로',
#  '국군부대를',
#  'UAE에',
#  '파견하려는',
#  '것임',
#  '나',
#  '파견경위',
#  '및',
#  '경과',
#  '09',
#  '12',
#  '한',
#  'UAE관계가',
#  '포괄적',
#  '전략적',
#  '동반자',
#  '관계',
#  '로',
#  '격상되고',
#  '군사협력관계도',
#  '강화',
#  '10',
#  '2',
#  'UAE군',
#  '총참모장',
#  '방한',
#  '시',
#  '군사협력',
#  '방안을',
#  '폭넓게',
#  '논의한',
#  '이후',
#  '군사협력이',
#  '급속히',
#  '발전',
#  '10',
#  '5',
#  'UAE',
#  '국빈',
#  '방한으로',
#  '군사협력',
#  '심화',
#  '확대계기',
#  '마련',
#  '특전사',
#  '방문',
#  '시',
#  '한국',
#  '특전부대의',
#  '우수성을',
#  '매우',
#  '높이',
#  '평가',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '세부협력',
#  '방안',
#  '발전',
#  '요청',
#  '10',
#  '8',
#  '국방장관의',
#  'UAE',
#  '방문',
#  '시',
#  'UAE측이',
#  '한국군',
#  '특전부대의',
#  'UAE',
#  '파견과',
#  '긴밀한',
#  '훈련협력을',
#  '우리측에',
#  '요청',
#  '10',
#  '10',
#  '군',
#  '현지',
#  '실사단',
#  '파견',
#  '부대',
#  '파견',
#  '여건',
#  '확인',
#  '점검',
#  '10',
#  '11',
#  '외교부',
#  '기획재정부',
#  '등과',
#  '부대',
#  '파견계획',
#  '협조',
#  '완료',
#  '10',
#  '11',
#  '9',
#  '국무회의',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육',
#  '훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '심의',
#  '의결',
#  '5',
#  '2',
#  '기본',
#  '계획',
#  '6',
#  '가',
#  '파견부대',
#  '규모',
#  '150명',
#  '이내',
#  '1진',
#  '130명',
#  '특전사',
#  '위주',
#  '특수전',
#  '교육훈련',
#  '지원',
#  '및',
#  '연합훈련을',
#  '위한',
#  '최소규모의',
#  '단위부대',
#  '편성',
#  '나',
#  '파견',
#  '지역',
#  'UAE',
#  '아부다비주',
#  '알',
#  '아인',
#  '소재',
#  '특수전',
#  '학교',
#  '다',
#  '임',
#  '무',
#  'UAE군',
#  '특수전',
#  '부대에',
#  '대한',
#  '교육훈련',
#  '지원',
#  'UAE군',
#  '특수전',
#  '부대와의',
#  '연합훈련',
#  '및',
#  '연습',
#  '유사시',
#  '우리',
#  '국민',
#  '보호',
#  '라',
#  '파견',
#  '기간',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '필요시',
#  '협조장교',
#  '및',
#  '선발대',
#  '인원은',
#  '사전에',
#  '파견',
#  '마',
#  '부대',
#  '교대',
#  '4',
#  '6개월',
#  '주기로',
#  '현지에서',
#  '임무교대',
#  '바',
#  '파견부대',
#  '지휘',
#  '부대',
#  '지휘권은',
#  '한국군이',
#  '보유',
#  '합동참모의장이',
#  '작전',
#  '지휘',
#  '육본',
#  '및',
#  '특전사에서',
#  '전투근무지원',
#  '및',
#  '교육훈련',
#  '지도감독',
#  '사',
#  '부대파견',
#  '및',
#  '임무수행',
#  '경비는',
#  '우리',
#  '정부가',
#  '부담',
#  '부대',
#  '주둔',
#  '시설',
#  '훈련장',
#  '등은',
#  'UAE',
#  '측에서',
#  '제공',
#  '3',
#  '예산',
#  '소요',
#  '가',
#  '11년도',
#  '소요예산',
#  '약',
#  '137억원',
#  '나',
#  '예산조치',
#  '국회',
#  '동의',
#  '후',
#  '2011년도',
#  '예산안에',
#  '대한',
#  '국회',
#  '심의',
#  '과정에서',
#  '반영',
#  '추진',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '비용추계서',
#  '1',
#  '비용추계',
#  '요약',
#  '가',
#  '재정수반요인',
#  '부대의',
#  '파견경비는',
#  '우리',
#  '정부의',
#  '부담으로',
#  '함',
#  '나',
#  '비용추계의',
#  '전제',
#  '국군부대의',
#  'UAE',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '파견',
#  '연장',
#  '기간',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '파견부대',
#  '규모',
#  '150명',
#  '이내',
#  '다',
#  '비용추계의',
#  '결과',
#  '연',
#  '도',
#  '구',
#  '분',
#  '인',
#  '건',
#  '비',
#  '운',
#  '영',
#  '비',
#  '소',
#  '계',
#  'a',
#  '소',
#  '계',
#  'b',
#  '지',
#  '출',
#  '수',
#  '입',
#  '2011',
#  '2',
#  '398',
#  '11',
#  '312',
#  '13',
#  '710',
#  '2012',
#  '2',
#  '398',
#  '5',
#  '383',
#  '7',
#  '781',
#  '단위',
#  '백만원',
#  '합',
#  '계',
#  '4',
#  '796',
#  '16',
#  '695',
#  '21',
#  '491',
#  '총',
#  '비용',
#  'a',
#  'b',
#  '13',
#  '710',
#  '7',
#  '781',
#  '21',
#  '491',
#  '라',
#  '부대의견',
#  '없음',
#  '마',
#  '작성자',
#  '작성자',
#  '이름',
#  '국방부',
#  '국제평화협력과장',
#  '대령',
#  '유재익',
#  '연락처',
#  '02',
#  '748',
#  '6350',
#  '7',
#  '8',
#  '2',
#  '비용추계의',
#  '상세내역',
#  '가',
#  '지',
#  '출',
#  '부대',
#  '운영',
#  '유지',
#  '비용',
#  '21',
#  '491백만원',
#  '단위',
#  '백만원',
#  '구',
#  '분',
#  '계',
#  '해외파견근무수당',
#  '증',
#  '식',
#  '피',
#  '복',
#  '비',
#  '수',
#  '송',
#  '비',
#  '장비',
#  '물자',
#  '획득',
#  '유지비',
#  '기타',
#  '부대',
#  '운영비',
#  '2011',
#  '13',
#  '710',
#  '2',
#  '398',
#  '1',
#  '335',
#  '1',
#  '772',
#  '6',
#  '074',
#  '2',
#  '131',
#  '나',
#  '수',
#  '입',
#  '2012',
#  '7',
#  '781',
#  '2',
#  '398',
#  '1',
#  '315',
#  '1',
#  '072',
#  '913',
#  '2',
#  '083',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '재원조달계획서',
#  '1',
#  '부문별',
#  '재원분담계획',
#  '단위',
#  '백만원',
#  '연',
#  '도',
#  '구',
#  '분',
#  '중앙정부',
#  '일반회계',
#  '예',
#  '비',
#  '비',
#  '지방자치단계',
#  '그',
#  '밖의',
#  '공공단체',
#  '민',
#  '간',
#  '합',
#  '계',
#  '2011',
#  '13',
#  '710',
#  '13',
#  '710',
#  '2012이후',
#  '합',
#  '계',
#  '7',
#  '781',
#  '7',
#  '781',
#  '21',
#  '491',
#  '21',
#  '491',
#  '13',
#  '710',
#  '7',
#  '781',
#  '21',
#  '491',
#  '2',
#  '재원조달의',
#  '구체적인',
#  '방안',
#  '국군부대의',
#  'UAE군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안에',
#  '따른',
#  '소요예산은',
#  '2011년도',
#  '정부예산에서',
#  '137억원을',
#  '지출할',
#  '예정임',
#  '3',
#  '부대의견',
#  '없음',
#  '4',
#  '협의사항',
#  '국회동의',
#  '결과에',
#  '따라',
#  '기획재정부와',
#  '협의함',
#  '5',
#  '작성자',
#  '작성자',
#  '이름',
#  '국방부',
#  '국제평화협력과장',
#  '대령',
#  '유재익',
#  '연락처',
#  '02',
#  '748',
#  '6350',
#  '9',
#  '10',
#  '의안',
#  '소관',
#  '부서명',
#  '국방부',
#  '국방정책',
#  '실',
#  '국제평화협력',
#  '과',
#  '연',
#  '락',
#  '처',
#  '02',
#  '748',
#  '6350']

# %%
nltk.word_tokenize(doc_ko)

# %%
Okt().nouns('아버지가방에 들어가신다.')
# Out:
# ['아버지', '가방']

# %%
#nltk.regexp_span_tokenize('아바지 가방에 들어가신다.')

# %%
from konlpy.tag import Kkma, Komoran, Mecab, Okt

okt = Okt()
okt.nouns(doc_ko), Okt()
# Out:
# (['국군',
#   '부대',
#   '아랍에미리트',
#   '군',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '관',
#   '파견',
#   '의안',
#   '의안',
#   '제출',
#   '연월일',
#   '번호',
#   '제',
#   '자',
#   '정',
#   '부',
#   '제안',
#   '이유',
#   '요청',
#   '협의',
#   '국익',
#   '창',
#   '지역',
#   '우리',
#   '특',
#   '부대',
#   '임무',
#   '수행',
#   '능력',
#   '향상',
#   '등',
#   '목적',
#   '국군',
#   '부대',
#   '파견',
#   '것임',
#   '나',
#   '국군',
#   '부대',
#   '파견',
#   '계기',
#   '우리',
#   '특',
#   '부대',
#   '전투력',
#   '향상',
#   '대한',
#   '방산수',
#   '협력',
#   '확대',
#   '국방',
#   '운영체계',
#   '수출',
#   '예비역',
#   '및',
#   '민간',
#   '전문',
#   '인력',
#   '진출',
#   '양국',
#   '경제',
#   '협력',
#   '확대',
#   '등',
#   '기대',
#   '내용',
#   '국군',
#   '부대',
#   '임무',
#   '군',
#   '특수전',
#   '부대',
#   '대한',
#   '교육',
#   '훈련',
#   '지원',
#   '군',
#   '특수전',
#   '부대',
#   '연합',
#   '훈련',
#   '및',
#   '연습',
#   '유사시',
#   '우리',
#   '국민',
#   '보호',
#   '임',
#   '나',
#   '파견',
#   '규모',
#   '명',
#   '이내',
#   '파견',
#   '지역',
#   '아부다비',
#   '주',
#   '알아인',
#   '소재',
#   '특수전',
#   '학교',
#   '임',
#   '파견',
#   '기간',
#   '부대',
#   '지휘',
#   '한국',
#   '보유',
#   '우리',
#   '합동',
#   '참모',
#   '의장',
#   '작전',
#   '마',
#   '국군',
#   '부대',
#   '파견',
#   '경비',
#   '우리',
#   '정부',
#   '부담',
#   '함',
#   '참고',
#   '사항',
#   '관련',
#   '법령',
#   '헌법',
#   '제',
#   '제',
#   '항',
#   '나',
#   '예산',
#   '조치',
#   '국회',
#   '동의',
#   '후',
#   '예산안',
#   '대한',
#   '국회',
#   '심의',
#   '과정',
#   '반영',
#   '추진',
#   '합',
#   '의',
#   '외교통상부',
#   '기획재정부',
#   '합의',
#   '국군',
#   '부대',
#   '아랍에미리트',
#   '군',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '관',
#   '파견',
#   '의안',
#   '군',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '위해',
#   '명',
#   '이내',
#   '국군',
#   '부대',
#   '파견',
#   '것',
#   '헌법',
#   '제',
#   '제',
#   '항의',
#   '규정',
#   '동의',
#   '국군',
#   '부대',
#   '파견',
#   '목적',
#   '및',
#   '경과',
#   '파견',
#   '목적',
#   '요청',
#   '협의',
#   '국익',
#   '창',
#   '지역',
#   '우리',
#   '특',
#   '부대',
#   '임무',
#   '수행',
#   '능력',
#   '향상',
#   '등',
#   '목적',
#   '국군',
#   '부대',
#   '파견',
#   '것임',
#   '나',
#   '파견',
#   '경위',
#   '및',
#   '경과',
#   '관계',
#   '포괄',
#   '전략',
#   '동반',
#   '관계',
#   '로',
#   '격상',
#   '군사',
#   '협력',
#   '관계도',
#   '강화',
#   '군',
#   '참모',
#   '방한',
#   '시',
#   '군사',
#   '협력',
#   '방안',
#   '논의',
#   '이후',
#   '군사',
#   '협력',
#   '발전',
#   '국빈',
#   '방한',
#   '군사',
#   '협력',
#   '심화',
#   '확대',
#   '계기',
#   '마련',
#   '특전사',
#   '방문',
#   '시',
#   '한국',
#   '특',
#   '부대',
#   '우수',
#   '매우',
#   '높이',
#   '평가',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '세부',
#   '협력',
#   '방안',
#   '발전',
#   '요청',
#   '국방',
#   '장관',
#   '방문',
#   '시',
#   '측',
#   '한국',
#   '특',
#   '부대',
#   '파견',
#   '훈련',
#   '협력',
#   '우리',
#   '요청',
#   '군',
#   '현지',
#   '실',
#   '사단',
#   '파견',
#   '부대',
#   '파견',
#   '여건',
#   '확인',
#   '점검',
#   '외교부',
#   '기획재정부',
#   '등',
#   '부대',
#   '파견',
#   '계획',
#   '협조',
#   '완료',
#   '국무회의',
#   '국군',
#   '부대',
#   '아랍에미리트',
#   '군',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '관',
#   '파견',
#   '의안',
#   '심의',
#   '의결',
#   '기본',
#   '계획',
#   '파견',
#   '부대',
#   '규모',
#   '명',
#   '이내',
#   '진',
#   '명',
#   '특전사',
#   '위주',
#   '특수전',
#   '교육',
#   '훈련',
#   '지원',
#   '및',
#   '연합',
#   '훈련',
#   '위',
#   '최소',
#   '규모',
#   '단위',
#   '부대',
#   '편성',
#   '나',
#   '파견',
#   '지역',
#   '아부다비',
#   '주',
#   '알',
#   '아인',
#   '소재',
#   '특수전',
#   '학교',
#   '임',
#   '무',
#   '군',
#   '특수전',
#   '부대',
#   '대한',
#   '교육',
#   '훈련',
#   '지원',
#   '군',
#   '특수전',
#   '부대',
#   '연합',
#   '훈련',
#   '및',
#   '연습',
#   '유사시',
#   '우리',
#   '국민',
#   '보호',
#   '파견',
#   '기간',
#   '필요시',
#   '협조',
#   '장교',
#   '및',
#   '선발',
#   '인원',
#   '사전',
#   '파견',
#   '마',
#   '부대',
#   '교대',
#   '개월',
#   '주기',
#   '현지',
#   '임무',
#   '교대',
#   '바',
#   '파견',
#   '부대',
#   '지휘',
#   '부대',
#   '지휘',
#   '한국',
#   '보유',
#   '합동',
#   '참모',
#   '의장',
#   '작전',
#   '지휘',
#   '및',
#   '특전사',
#   '전투',
#   '근무',
#   '지원',
#   '및',
#   '교육',
#   '훈련',
#   '지도',
#   '감독',
#   '사',
#   '부대',
#   '파견',
#   '및',
#   '임무',
#   '수행',
#   '경비',
#   '우리',
#   '정부',
#   '부담',
#   '부대',
#   '주둔',
#   '시설',
#   '훈련',
#   '등',
#   '측',
#   '제공',
#   '예산',
#   '소요',
#   '소요',
#   '예산',
#   '약',
#   '나',
#   '예산',
#   '조치',
#   '국회',
#   '동의',
#   '후',
#   '예산안',
#   '대한',
#   '국회',
#   '심의',
#   '과정',
#   '반영',
#   '추진',
#   '국군',
#   '부대',
#   '아랍에미리트',
#   '군',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '관',
#   '파견',
#   '의안',
#   '비용',
#   '추계',
#   '비용',
#   '추계',
#   '요약',
#   '재정',
#   '요인',
#   '부대',
#   '파견',
#   '경비',
#   '우리',
#   '정부',
#   '부담',
#   '함',
#   '나',
#   '비용',
#   '추계',
#   '전제',
#   '국군',
#   '부대',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '관',
#   '파견',
#   '의안',
#   '파견',
#   '연장',
#   '기간',
#   '파견',
#   '부대',
#   '규모',
#   '명',
#   '이내',
#   '비용',
#   '추계',
#   '결과',
#   '연',
#   '도',
#   '구',
#   '분',
#   '인',
#   '건',
#   '비',
#   '운',
#   '영',
#   '비',
#   '소',
#   '계',
#   '소',
#   '계',
#   '수',
#   '입',
#   '단위',
#   '백만원',
#   '합',
#   '계',
#   '총',
#   '비용',
#   '부대',
#   '의견',
#   '마',
#   '작성자',
#   '작성자',
#   '이름',
#   '국방부',
#   '국제',
#   '평화',
#   '협력',
#   '과장',
#   '대령',
#   '유재',
#   '익',
#   '연락처',
#   '비용',
#   '추계',
#   '상세',
#   '역',
#   '부대',
#   '운영',
#   '유지',
#   '비용',
#   '백만원',
#   '단위',
#   '백만원',
#   '구',
#   '분',
#   '계',
#   '해외',
#   '파견',
#   '근무',
#   '수당',
#   '증',
#   '식',
#   '피',
#   '복',
#   '비',
#   '수',
#   '송',
#   '비',
#   '장비',
#   '물자',
#   '획득',
#   '유지비',
#   '기타',
#   '부대',
#   '운영',
#   '비',
#   '나',
#   '수',
#   '입',
#   '국군',
#   '부대',
#   '아랍에미리트',
#   '군',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '관',
#   '파견',
#   '의안',
#   '재원',
#   '조달',
#   '계획',
#   '부문',
#   '별',
#   '재원',
#   '분담',
#   '계획',
#   '단위',
#   '백만원',
#   '연',
#   '도',
#   '구',
#   '분',
#   '중앙정부',
#   '일반',
#   '회계',
#   '예',
#   '비',
#   '비',
#   '지방자치',
#   '단계',
#   '그',
#   '밖',
#   '단체',
#   '민',
#   '간',
#   '합',
#   '계',
#   '이후',
#   '합',
#   '계',
#   '재원',
#   '조달',
#   '구체',
#   '방안',
#   '국군',
#   '부대',
#   '군',
#   '교육',
#   '훈련',
#   '지원',
#   '등',
#   '관',
#   '파견',
#   '의안',
#   '예산',
#   '정부',
#   '예산',
#   '지출',
#   '예정',
#   '임',
#   '부대',
#   '의견',
#   '협의',
#   '사항',
#   '국회',
#   '동의',
#   '결과',
#   '기획재정부',
#   '협의',
#   '함',
#   '작성자',
#   '작성자',
#   '이름',
#   '국방부',
#   '국제',
#   '평화',
#   '협력',
#   '과장',
#   '대령',
#   '유재',
#   '익',
#   '연락처',
#   '의안',
#   '소관',
#   '부서',
#   '국방부',
#   '국방',
#   '정책',
#   '실',
#   '국제',
#   '평화',
#   '협력',
#   '과',
#   '연',
#   '락',
#   '처'],
#  <konlpy.tag._okt.Okt at 0x21332696160>)

# %%
okt.morphs(doc_ko)
# Out:
# ['국군',
#  '부대',
#  '의',
#  '아랍에미리트',
#  '(',
#  'UAE',
#  ')',
#  '군',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '에',
#  '관',
#  '한',
#  '파견',
#  '동',
#  '의안',
#  '\n\n',
#  '의안',
#  '\n                                                                  ',
#  '제출',
#  '연월일',
#  ':',
#  '2010',
#  '.',
#  '11',
#  '.',
#  '15',
#  '.',
#  '\n',
#  '9897',
#  '\n',
#  '번호',
#  '\n                                                                        ',
#  '제',
#  '출',
#  '자',
#  ':',
#  '정',
#  '부',
#  '\n\n',
#  '제안',
#  '이유',
#  '\n\n    ',
#  '가',
#  '.',
#  'UAE',
#  '측',
#  '요청',
#  '과',
#  '협의',
#  '에',
#  '따라',
#  ',',
#  '국익',
#  '창',
#  '출과',
#  '다양한',
#  '지역',
#  '에서의',
#  '우리',
#  '특',
#  '전',
#  '부대',
#  '임무',
#  '수행',
#  '능력',
#  '향상',
#  '등',
#  '을',
#  '목적',
#  '으로',
#  '국군',
#  '부대',
#  '를',
#  'UAE',
#  '에',
#  '파견',
#  '하려는',
#  '것임',
#  '.',
#  '\n\n    ',
#  '나',
#  '.',
#  '국군',
#  '부대',
#  '파견',
#  '을',
#  '계기',
#  '로',
#  '우리',
#  '특',
#  '전',
#  '부대',
#  '의',
#  '전투력',
#  '향상',
#  '은',
#  '물론',
#  ',',
#  'UAE',
#  '에',
#  '대한',
#  '방산수',
#  '출',
#  '협력',
#  '확대',
#  ',',
#  '국방',
#  '운영체계',
#  '수출',
#  ',',
#  '예비역',
#  '및',
#  '민간',
#  '전문',
#  '인력',
#  '진출',
#  ',',
#  '양국',
#  '간',
#  '경제',
#  '협력',
#  '확대',
#  '등',
#  '이',
#  '기대',
#  '됨',
#  '.',
#  '\n\n',
#  '주요',
#  '내용',
#  '\n\n    ',
#  '가',
#  '.',
#  '국군',
#  '부대',
#  '의',
#  '임무',
#  '는',
#  'UAE',
#  '군',
#  '특수전',
#  '부대',
#  '에',
#  '대한',
#  '교육',
#  '훈련',
#  '지원',
#  ',',
#  'UAE',
#  '군',
#  '특수전',
#  '부대',
#  '와',
#  '연합',
#  '훈련',
#  '및',
#  '연습',
#  ',',
#  '유사시',
#  '우리',
#  '국민',
#  '보호',
#  '임',
#  '.',
#  '나',
#  '.',
#  '파견',
#  '규모',
#  '는',
#  '150',
#  '명',
#  '이내',
#  '이며',
#  ',',
#  '파견',
#  '지역',
#  '은',
#  'UAE',
#  '아부다비',
#  '주',
#  '알아인',
#  '소재',
#  '특수전',
#  '학교',
#  '임',
#  '.',
#  '\n\n    ',
#  '다',
#  '.',
#  '파견',
#  '기간',
#  '은',
#  '2011년',
#  '1월',
#  '1일',
#  '부터',
#  '2012년',
#  '12월',
#  '31일',
#  '까지임',
#  '.',
#  '라',
#  '.',
#  '부대',
#  '지휘',
#  '권',
#  '은',
#  '한국',
#  '군',
#  '이',
#  '보유',
#  '하며',
#  '우리',
#  '합동',
#  '참모',
#  '의장',
#  '이',
#  '작전',
#  '지',
#  '휘함',
#  '.',
#  '마',
#  '.',
#  '국군',
#  '부대',
#  '의',
#  '파견',
#  '경비',
#  '는',
#  '우리',
#  '정부',
#  '의',
#  '부담',
#  '으로',
#  '함',
#  '.',
#  '참고',
#  '사항',
#  '\n\n      ',
#  '가',
#  '.',
#  '관련',
#  '법령',
#  ':',
#  '헌법',
#  '제',
#  '60조',
#  '제',
#  '2',
#  '항',
#  '\n\n      ',
#  '나',
#  '.',
#  '예산',
#  '조치',
#  ':',
#  '국회',
#  '동의',
#  '후',
#  '2011년',
#  '도',
#  '예산안',
#  '에',
#  '대한',
#  '국회',
#  '심의',
#  '과정',
#  '\n',
#  '에서',
#  '반영',
#  '추진',
#  '\n\n      ',
#  '다',
#  '.',
#  '합',
#  '의',
#  ':',
#  '외교통상부',
#  ',',
#  '기획재정부',
#  '와',
#  '합의',
#  '되었음',
#  '.',
#  '\n\n',
#  '-',
#  '1',
#  '-',
#  '\n\n\x0c',
#  '국군',
#  '부대',
#  '의',
#  '아랍에미리트',
#  '(',
#  'UAE',
#  ')',
#  '군',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '에',
#  '관',
#  '한',
#  '파견',
#  '동',
#  '의안',
#  '\n\n',
#  'UAE',
#  '군',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '을',
#  '위해',
#  '150',
#  '명',
#  '이내',
#  '의',
#  '국군',
#  '부대',
#  '를',
#  '2011년',
#  '1월',
#  '1일',
#  '부터',
#  '2012년',
#  '12월',
#  '31일',
#  '까지',
#  '2년',
#  '간',
#  'UAE',
#  '에',
#  '파견',
#  '하는',
#  '것',
#  '을',
#  '헌법',
#  '제',
#  '60조',
#  '제',
#  '2',
#  '항의',
#  '규정',
#  '에',
#  '따라',
#  '동의',
#  '한다',
#  '.',
#  '-',
#  '3',
#  '-',
#  '\n\n\x0c',
#  '1',
#  '.',
#  '국군',
#  '부대',
#  '파견',
#  '목적',
#  '및',
#  '경과',
#  '\n\n',
#  '가',
#  '.',
#  '파견',
#  '목적',
#  '\n\n',
#  'UAE',
#  '측',
#  '요청',
#  '과',
#  '협의',
#  '에',
#  '따라',
#  ',',
#  '국익',
#  '창',
#  '출과',
#  '다양한',
#  '지역',
#  '에서의',
#  '우리',
#  '특',
#  '전',
#  '부대',
#  '임무',
#  '수행',
#  '능력',
#  '향상',
#  '등',
#  '을',
#  '목적',
#  '으로',
#  '국군',
#  '부대',
#  '를',
#  'UAE',
#  '에',
#  '파견',
#  '하려는',
#  '것임',
#  '.',
#  '나',
#  '.',
#  '파견',
#  '경위',
#  '및',
#  '경과',
#  '\n\n          ',
#  '○',
#  '’',
#  '09',
#  '.',
#  '12',
#  '한',
#  '-',
#  'UAE',
#  '관계',
#  '가',
#  '‘',
#  '포괄',
#  '적',
#  '‧',
#  '전략',
#  '적',
#  '동반',
#  '자',
#  '관계',
#  '’',
#  '로',
#  '격상',
#  '되고',
#  '군사',
#  '협력',
#  '관계도',
#  '강화',
#  '\n\n          ',
#  '○',
#  '’',
#  '10',
#  '.',
#  '2',
#  'UAE',
#  '군',
#  '총',
#  '참모',
#  '장',
#  '방한',
#  '시',
#  '군사',
#  '협력',
#  '방안',
#  '을',
#  '폭넓게',
#  '논의',
#  '한',
#  '이후',
#  ',',
#  '군사',
#  '협력',
#  '이',
#  '급속히',
#  '발전',
#  '\n\n          ',
#  '○',
#  '’',
#  '10',
#  '.',
#  '5',
#  'UAE',
#  '국빈',
#  '방한',
#  '으로',
#  '군사',
#  '협력',
#  '심화',
#  '‧',
#  '확대',
#  '계기',
#  '마련',
#  '\n\n                ',
#  '∙',
#  '특전사',
#  '방문',
#  '시',
#  '한국',
#  '특',
#  '전',
#  '부대',
#  '의',
#  '우수',
#  '성',
#  '을',
#  '매우',
#  '높이',
#  '평가',
#  ',',
#  '교육',
#  '\n\n',
#  '훈련',
#  '지원',
#  '등',
#  '세부',
#  '협력',
#  '방안',
#  '발전',
#  '요청',
#  '\n\n          ',
#  '○',
#  '’',
#  '10',
#  '.',
#  '8',
#  '국방',
#  '장관',
#  '의',
#  'UAE',
#  '방문',
#  '시',
#  'UAE',
#  '측',
#  '이',
#  '한국',
#  '군',
#  '특',
#  '전',
#  '부대',
#  '의',
#  'UAE',
#  '파견',
#  '과',
#  '긴밀한',
#  '훈련',
#  '협력',
#  '을',
#  '우리',
#  '측',
#  '에',
#  '요청',
#  '○',
#  '’',
#  '10',
#  '.',
#  '10',
#  '군',
#  '현지',
#  '실',
#  '사단',
#  '파견',
#  ',',
#  '부대',
#  '파견',
#  '여건',
#  '확인',
#  '‧',
#  '점검',
#  '\n\n          ',
#  '○',
#  '’',
#  '10',
#  '.',
#  '11',
#  '외교부',
#  ',',
#  '기획재정부',
#  '등',
#  '과',
#  '부대',
#  '파견',
#  '계획',
#  '협조',
#  '완료',
#  '\n\n          ',
#  '○',
#  '’',
#  '10',
#  '.',
#  '11',
#  '.',
#  '9',
#  '국무회의',
#  ',',
#  '｢',
#  '국군',
#  '부대',
#  '의',
#  '아랍에미리트',
#  '(',
#  'UAE',
#  ')',
#  '군',
#  '교육',
#  '\n',
#  '훈련',
#  '지원',
#  '등',
#  '에',
#  '관',
#  '한',
#  '파견',
#  '동',
#  '의안',
#  '｣',
#  '심의',
#  '·',
#  '의결',
#  '\n\n',
#  '-',
#  '5',
#  '-',
#  '\n\n\x0c',
#  '2',
#  '.',
#  '기본',
#  '계획',
#  '\n\n',
#  '-',
#  '6',
#  '-',
#  '\n\n    ',
#  '가',
#  '.',
#  '파견',
#  '부대',
#  '규모',
#  ':',
#  '150',
#  '명',
#  '이내',
#  '(',
#  '1',
#  '진',
#  '130',
#  '명',
#  ',',
#  '특전사',
#  '위주',
#  ')',
#  '\n\n     ',
#  '*',
#  '특수전',
#  '교육',
#  '훈련',
#  '지원',
#  '및',
#  '연합',
#  '훈련',
#  '을',
#  '위',
#  '한',
#  '최소',
#  '규모',
#  '의',
#  '단위',
#  '부대',
#  '편성',
#  '\n\n    ',
#  '나',
#  '.',
#  '파견',
#  '지역',
#  ':',
#  'UAE',
#  '아부다비',
#  '주',
#  '알',
#  '아인',
#  '소재',
#  '특수전',
#  '학교',
#  '\n\n    ',
#  '다',
#  '.',
#  '임',
#  '무',
#  '○',
#  'UAE',
#  '군',
#  '특수전',
#  '부대',
#  '에',
#  '대한',
#  '교육',
#  '훈련',
#  '지원',
#  '\n\n          ',
#  '○',
#  'UAE',
#  '군',
#  '특수전',
#  '부대',
#  '와의',
#  '연합',
#  '훈련',
#  '및',
#  '연습',
#  '\n\n          ',
#  '○',
#  '유사시',
#  '우리',
#  '국민',
#  '보호',
#  '\n\n    ',
#  '라',
#  '.',
#  '파견',
#  '기간',
#  ':',
#  '2011년',
#  '1월',
#  '1일',
#  '부터',
#  '2012년',
#  '12월',
#  '31일',
#  '까지',
#  '\n\n          ',
#  '○',
#  '필요시',
#  '협조',
#  '장교',
#  '및',
#  '선발',
#  '대',
#  '인원',
#  '은',
#  '사전',
#  '에',
#  '파견',
#  '\n\n    ',
#  '마',
#  '.',
#  '부대',
#  '교대',
#  ':',
#  '4',
#  '～',
#  '6',
#  '개월',
#  '주기',
#  '로',
#  '현지',
#  '에서',
#  '임무',
#  '교대',
#  '\n\n    ',
#  '바',
#  '.',
#  '파견',
#  '부대',
#  '지휘',
#  '○',
#  '부대',
#  '지휘',
#  '권',
#  '은',
#  '한국',
#  '군',
#  '이',
#  '보유',
#  '\n\n          ',
#  '○',
#  '합동',
#  '참모',
#  '의장',
#  '이',
#  '작전',
#  '지휘',
#  '\n\n          ',
#  '*',
#  '육',
#  '본',
#  '및',
#  '특전사',
#  '에서',
#  '전투',
#  '근무',
#  '지원',
#  '및',
#  '교육',
#  '훈련',
#  '지도',
#  '감독',
#  '사',
#  '.',
#  '부대',
#  '파견',
#  '및',
#  '임무',
#  '수행',
#  '경비',
#  '는',
#  '우리',
#  '정부',
#  '가',
#  '부담',
#  '*',
#  '부대',
#  '주둔',
#  '시설',
#  ',',
#  '훈련',
#  '장',
#  '등',
#  '은',
#  'UAE',
#  '측',
#  '에서',
#  '제공',
#  '\n\n',
#  '3',
#  '.',
#  '예산',
#  '소요',
#  '\n\n    ',
#  '가',
#  '.',
#  "'",
#  '11년',
#  '도',
#  '소요',
#  '예산',
#  ':',
#  '약',
#  '137억원',
#  '\n\n    ',
#  '나',
#  '.',
#  '예산',
#  '조치',
#  ':',
#  '국회',
#  '동의',
#  '후',
#  '2011년',
#  '도',
#  '예산안',
#  '에',
#  '대한',
#  '국회',
#  '심의',
#  '과정',
#  '에서',
#  '반영',
#  '추진',
#  '\n\n\x0c',
#  '국군',
#  '부대',
#  '의',
#  '아랍에미리트',
#  '(',
#  'UAE',
#  ')',
#  '군',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '에',
#  '관',
#  '한',
#  '파견',
#  '동',
#  '의안',
#  '비용',
#  '추계',
#  '서',
#  '\n\n',
#  '1',
#  '.',
#  '비용',
#  '추계',
#  '요약',
#  '\n\n    ',
#  '가',
#  '.',
#  '재정',
#  '수',
#  '반',
#  '요인',
#  ':',
#  '부대',
#  '의',
#  '파견',
#  '경비',
#  '는',
#  '우리',
#  '정부',
#  '의',
#  '부담',
#  '으로',
#  '함',
#  '.',
#  '\n\n    ',
#  '나',
#  '.',
#  '비용',
#  '추계',
#  '의',
#  '전제',
#  ':',
#  '국군',
#  '부대',
#  '의',
#  'UAE',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '에',
#  '관',
#  '한',
#  '파견',
#  '동',
#  '의안',
#  '\n\n          ',
#  '○',
#  '파견',
#  '연장',
#  '기간',
#  ':',
#  '2011년',
#  '1월',
#  '1일',
#  '부터',
#  '2012년',
#  '12월',
#  '31일',
#  '까지',
#  '\n\n          ',
#  '○',
#  '파견',
#  '부대',
#  '규모',
#  ':',
#  '150',
#  '명',
#  '이내',
#  '\n\n    ',
#  '다',
#  '.',
#  '비용',
#  '추계',
#  '의',
#  '결과',
#  '\n\n                                          ',
#  '연',
#  '도',
#  '구',
#  '분',
#  '\n\n  ',
#  '◦',
#  '인',
#  '건',
#  '비',
#  '\n\n  ',
#  '◦',
#  '운',
#  '영',
#  '비',
#  '\n\n',
#  '소',
#  '계',
#  '(',
#  'a',
#  ')',
#  '\n\n',
#  '-',
#  '\n\n',
#  '소',
#  '계',
#  '(',
#  'b',
#  ')',
#  '\n\n',
#  '지',
#  '\n\n',
#  '출',
#  '\n\n',
#  '수',
#  '\n',
#  '입',
#  '\n\n \n\n',
#  '2011',
#  '\n\n',
#  '2,398',
#  '\n\n',
#  '11,312',
#  '\n\n',
#  '13,710',
#  '\n\n',
#  '-',
#  '\n\n',
#  '-',
#  '\n\n',
#  ...]

# %% [markdown]
# ### 한국어 형태소 분석
#
# - 한글 형태소 분석기
#    - `konlp.tag.[분석기].morphs()`
#    - `konlp.tag.[분석기].nouns()`

# %%
morphs = Okt().morphs('아버지가 방에 들어가신다. 그 방에는 내 동생이 있다.')
morphs
# Out:
# ['아버지', '가', '방', '에', '들어가신다', '.', '그', '방', '에는', '내', '동생', '이', '있다', '.']

# %%
morphs = Okt().morphs('아버지가방에 들어가신다. 그 방에는 내 동생이 있다.')
morphs
# Out:
# ['아버지', '가방', '에', '들어가신다', '.', '그', '방', '에는', '내', '동생', '이', '있다', '.']

# %%
morphs = Kkma().morphs('아버지가 방에 들어가신다. 그 방에는 내 동생이 있다.')
morphs
# Out:
# ['아버지',
#  '가',
#  '방',
#  '에',
#  '들어가',
#  '시',
#  'ㄴ다',
#  '.',
#  '그',
#  '방',
#  '에',
#  '는',
#  '내',
#  '동생',
#  '이',
#  '있',
#  '다',
#  '.']

# %%
morphs = Kkma().morphs('아버지가방에 들어가신다. 그 방에는 내 동생이 있다.')
morphs

# %%
morphs = Hannanum().morphs('아버지가 방에 들어가신다. 그 방에는 내 동생이 있다.')
morphs

# %%
morphs = Hannanum().morphs('아버지가방에 들어가신다. 그 방에는 내 동생이 있다.')
morphs

# %% [markdown]
# ### 한국어 품사 태깅
#
# 텍스트를 태그하는 길은 여러가지 있다. 아주 자주 사용하는 것으로 POS 태깅이 있다.
#
# 형태소 분석기의 `.pos()` 함수는  사용해서 행태소의 품사를 얻어서 **(<형태소>,<품사>)** 튜플 리스트를 반환한다.

# %%
Kkma().sentences('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')
# Out:
# ['자연어처리 (NLP) 가 한국어에서 특히 어려운 4가지 이유! 왜?']

# %%
Kkma().sentences(doc_ko)
# Out:
# ['국군부대의 아랍에 미리트 (UAE) 군 교육훈련 지원 등에 관한 파견 동의 안 의안 제출 연월일 : 2010. 11. 15. 9897 번호 제 출 자 : 정 부 제안 이유 가. UAE 측 요청과 협의에 따라, 국익 창출과 다양한 지역에서의 우리 특전부대 임무수행능력 향상 등을 목적으로 국군부대를 UAE에 파견하려는 것임. 나. 국군부대 파견을 계기로 우리 특전부대의 전투력 향상은 물론, UAE에 대한 방산 수출협력 확대, 국방운영체계 수출, 예비역 및 민간 전문인력 진출, 양국 간 경제협력 확대 등이 기대됨. 주요 내용 가. 국군부대의 임무는 UAE 군 특수 전 부대에 대한 교육훈련 지원, UAE 군 특수 전 부대와 연합훈련 및 연습, 유사시 우리 국민 보호 임. 나. 파견 규모는 150명 이내이며, 파견지역은 UAE 아부 다비주 알아 인 소재 특수 전학교 임. 다.',
#  '파견기간은 2011년 1월 1일부터 2012년 12월 31일까지 임. 라.',
#  '부대 지휘권은 한국군이 보유하며 우리 합동 참모의장이 작전 지휘함. 마. 국군부대의 파견경비는 우리 정부의 부담으로 함. 참고 사항 가. 관련 법령 : 헌법 제 60조 제 2 항 나. 예산조치 : 국회 동의 후 2011년도 예산안에 대한 국회 심의 과정 에서 반영 추진 다. 합 의 : 외교통 상부, 기획 재정부와 합의되었음. - 1 - \x0c 국 군부대의 아랍에 미리트 (UAE) 군 교육훈련 지원 등에 관한 파견 동의 안 UAE 군 교육훈련 지원 등을 위해 150명 이내의 국군부대를 2011년 1월 1일부터 2012년 12월 31일까지 2년 간 UAE에 파견하는 것을 헌법 제 60조 제 2 항의 규정에 따라 동의한다.',
#  '- 3 - \x0c1. 국군부대 파견 목적 및 경과 가. 파견목적 UAE 측 요청과 협의에 따라, 국익 창출과 다양한 지역에서의 우리 특전부대 임무수행능력 향상 등을 목적으로 국군부대를 UAE에 파견하려는 것임. 나. 파견 경위 및 경과 ○ ’09. 12 한 -UAE 관계가 ‘ 포괄적‧ 전략적 동반자 관계’ 로 격상되고 군사협력관계도 강화 ○ ’10. 2 UAE 군 총 참모장 방한 시 군사협력 방안을 폭넓게 논의한 이후, 군사협력이 급속히 발전 ○ ’10. 5 UAE 국빈 방한으로 군사협력 심화‧ 확대 계기 마련 ∙ 특전사 방문 시 한국 특전부대의 우수성을 매우 높이 평가, 교육 훈련 지원 등 세부협력 방안 발전 요청 ○ ’10. 8 국방장관의 UAE 방문 시 UAE 측이 한국군 특전부대의 UAE 파견과 긴밀한 훈련협력을 우리 측에 요청 ○ ’10. 10 군 현지 실 사단 파견, 부대 파견 여건 확인‧ 점검 ○ ’10. 11 외 교부, 기획 재정부 등과 부대 파견계획 협조 완료 ○ ’10. 11. 9 국 무회의, ｢ 국 군부대의 아랍에 미리트 (UAE) 군 교육 훈련 지원 등에 관한 파견 동의 안｣ 심의· 의결 - 5 - \x0c2. 기본 계획 - 6 - 가. 파견부대 규모 : 150명 이내 ( 1 진 130명, 특전사 위주 ) * 특수 전 교육훈련 지원 및 연합훈련을 위한 최소규모의 단위부대 편성 나. 파견 지역 : UAE 아부 다비 주 알 아인 소재 특수 전 학교 다.',
#  '임 무 ○ UAE 군 특수 전 부대에 대한 교육훈련 지원 ○ UAE 군 특수 전 부대와의 연합훈련 및 연습 ○ 유사 시 우리 국민 보호 라.',
#  "파견 기간 : 2011년 1월 1일부터 2012년 12월 31일까지 ○ 필요시 협조 장교 및 선발대 인원은 사전에 파견 마. 부대 교대 : 4 ～ 6개월 주기로 현지에서 임무 교대 바. 파견부대 지휘 ○ 부대 지휘권은 한국군이 보유 ○ 합동 참모의장이 작전 지휘 * 육본 및 특전사에서 전투근무지원 및 교육훈련 지도 감독 사. 부대 파견 및 임무수행 경비는 우리 정부가 부담 * 부대 주둔 시설, 훈련장 등은 UAE 측에서 제공 3. 예산 소요 가. '11 년도 소요 예산 : 약 137억원 나. 예산조치 : 국회 동의 후 2011년도 예산안에 대한 국회 심의 과정에서 반영 추진 \x0c 국 군부대의 아랍에 미리트 (UAE) 군 교육훈련 지원 등에 관한 파견 동의 안 비용 추계서 1. 비용 추계 요약 가. 재정 수반요인 : 부대의 파견경비는 우리 정부의 부담으로 함. 나. 비용 추계의 전제 : 국군부대의 UAE 교육훈련 지원 등에 관한 파견 동의 안 ○ 파견 연장 기간 : 2011년 1월 1일부터 2012년 12월 31일까지 ○ 파견부대 규모 : 150명 이내 다.",
#  '비용 추계의 결과 연 도 구 분 ◦ 인 건 비 ◦ 운 영 비 소 계 (a) - 소 계 (b) 지 출 수 입 2011 2,398 11,312 13,710 - - 2012 2,398 5,383 7,781 - - 단위 : 백만 원 합 계 4,796 16,695 21,491 - - □ 총 비용 (a-b) 13,710 7,781 21,491 라.',
#  '부대 의견 : 없음. 마. 작성자 : 작성자 이름 국방부 국제평화협력과장 대령 유 재익 연락처 02) 748 - 6350 - 7 - \x0c- 8 - 2. 비용 추계의 상 세 내역 가. 지 출 ○ 부대 운영 / 유지 비용 : 21,491백만원 단위 : 백만원 구 분 계 ◦ 해외 파견근무 수당 ◦ 증 식 / 피 복 비 ◦ 수 송 비 ◦ 장비 / 물자 획득‧ 유지비 ◦ 기타 부대 운영비 2011 13,710 2,398 1,335 1,772 6,074 2,131 나. 수 입 : - 2012 7,781 2,398 1,315 1,072 913 2,083 \x0c 국 군부대의 아랍에 미리트 (UAE) 군 교육훈련 지원 등에 관한 파견 동의 안 재원조달 계획서 1. 부문별 재원 분담계획 단위 : 백만원 연 도 구 분 □ 중앙정부 ◦ 일반 회계 ◦ 예 비 비 □ 지방자치단계 □ 그 밖의 공공단체 □ 민 간 □ 합 계 2011 13,710 13,710 - - - - 2012 이후 합 계 7,781 7,781 21,491 21,491 - - - - - - - - 13,710 7,781 21,491 2. 재원조달의 구체적인 방안 국군부대의 UAE 군 교육훈련 지원 등에 관한 파견 동의 안에 따른 소요 예산은 2011년도 정부 예산에서 137억원을 지출할 예정임. 3. 부대 의견 : 없음. 4. 협의사항 : 국회동의 결과에 따라 기획 재정부와 협의함. 5. 작성자 작성자 이름 국방부 국제평화협력과장 대령 유 재익 연락처 02) 748 - 6350 - 9 - \x0c- 10 - 〈 의 안 소관 부서명〉 국방부 국방정책 실 국제평화협력 과 연 락 처 (02) 748 - 6350']

# %%
Kkma().nouns('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')
# Out:
# ['자연어', '자연어처리', '처리', '한국어', '4', '4가지', '가지', '이유']

# %%
Kkma().pos('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')
# Out:
# [('자연어', 'NNG'),
#  ('처리', 'NNG'),
#  ('(', 'SS'),
#  ('NLP', 'OL'),
#  (')', 'SS'),
#  ('가', 'VV'),
#  ('아', 'ECS'),
#  ('한국어', 'NNG'),
#  ('에서', 'JKM'),
#  ('특히', 'MAG'),
#  ('어렵', 'VA'),
#  ('ㄴ', 'ETD'),
#  ('4', 'NR'),
#  ('가지', 'NNM'),
#  ('이유', 'NNG'),
#  ('!', 'SF'),
#  ('왜', 'MAG'),
#  ('?', 'SF')]

# %%
Kkma().pos('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')

# %%
Hannanum().nouns('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')

# %%
Hannanum().morphs('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')

# %%
Hannanum().pos('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')

# %%
Okt().nouns('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')

# %%
Okt().morphs('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')

# %%
Okt().pos('자연어처리(NLP)가 한국어에서 특히 어려운 4가지 이유! 왜?')

# %%
import nltk

# %% [markdown]
# ###  `nltk.Text()` 활용
#
#
# [nltk.text.Text](http://www.nltk.org/api/nltk.html#nltk.text.Text) 에서 제공하는 API 를 사용해 보자. 텍스트를 토큰으로 래핑해주는 기능이며 여러 메서드 (couting, concordanceing, collocation discovery...)는 분석의 다양성을 제공한다.
#
# - [class nltk.text.Text(tokens, name=None)](https://www.nltk.org/api/nltk.html?highlight=nltk%20text#nltk.text.Text)
#
# 들여온 문서는`nltk.Text()`는 문서 하나를 편리하게 탐색하도록 태그를 생성해 준다.

# %%
doc_ko = kobill.open('1809897.txt').read()
tokens_ko = nltk.regexp_tokenize(doc_ko, r'(\w+)')
tokens_ko
# Out:
# ['국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '의안',
#  '제출연월일',
#  '2010',
#  '11',
#  '15',
#  '9897',
#  '번호',
#  '제',
#  '출',
#  '자',
#  '정',
#  '부',
#  '제안이유',
#  '가',
#  'UAE측',
#  '요청과',
#  '협의에',
#  '따라',
#  '국익창출과',
#  '다양한',
#  '지역에서의',
#  '우리',
#  '특전부대',
#  '임무수행능력',
#  '향상',
#  '등을',
#  '목적으로',
#  '국군부대를',
#  'UAE에',
#  '파견하려는',
#  '것임',
#  '나',
#  '국군부대',
#  '파견을',
#  '계기로',
#  '우리',
#  '특전부대의',
#  '전투력',
#  '향상은',
#  '물론',
#  'UAE에',
#  '대한',
#  '방산수출협력',
#  '확대',
#  '국방운영체계',
#  '수출',
#  '예비역',
#  '및',
#  '민간',
#  '전문인력',
#  '진출',
#  '양국간',
#  '경제협력',
#  '확대',
#  '등이',
#  '기대됨',
#  '주요내용',
#  '가',
#  '국군부대의',
#  '임무는',
#  'UAE군',
#  '특수전',
#  '부대에',
#  '대한',
#  '교육훈련',
#  '지원',
#  'UAE군',
#  '특수전',
#  '부대와',
#  '연합훈련',
#  '및',
#  '연습',
#  '유사시',
#  '우리',
#  '국민',
#  '보호임',
#  '나',
#  '파견규모는',
#  '150명',
#  '이내이며',
#  '파견지역은',
#  'UAE',
#  '아부다비주',
#  '알아인',
#  '소재',
#  '특수전학교임',
#  '다',
#  '파견기간은',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지임',
#  '라',
#  '부대',
#  '지휘권은',
#  '한국군이',
#  '보유하며',
#  '우리',
#  '합동참모의장이',
#  '작전지휘함',
#  '마',
#  '국군부대의',
#  '파견경비는',
#  '우리',
#  '정부의',
#  '부담으로',
#  '함',
#  '참고사항',
#  '가',
#  '관련법령',
#  '헌법',
#  '제60조',
#  '제2항',
#  '나',
#  '예산조치',
#  '국회',
#  '동의',
#  '후',
#  '2011년도',
#  '예산안에',
#  '대한',
#  '국회',
#  '심의과정',
#  '에서',
#  '반영',
#  '추진',
#  '다',
#  '합',
#  '의',
#  '외교통상부',
#  '기획재정부와',
#  '합의되었음',
#  '1',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  'UAE군',
#  '교육훈련',
#  '지원',
#  '등을',
#  '위해',
#  '150명',
#  '이내의',
#  '국군부대를',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '2년간',
#  'UAE에',
#  '파견하는',
#  '것을',
#  '헌법',
#  '제60조',
#  '제2항의',
#  '규정에',
#  '따라',
#  '동의한다',
#  '3',
#  '1',
#  '국군부대',
#  '파견',
#  '목적',
#  '및',
#  '경과',
#  '가',
#  '파견목적',
#  'UAE측',
#  '요청과',
#  '협의에',
#  '따라',
#  '국익창출과',
#  '다양한',
#  '지역에서의',
#  '우리',
#  '특전부대',
#  '임무수행능력',
#  '향상',
#  '등을',
#  '목적으로',
#  '국군부대를',
#  'UAE에',
#  '파견하려는',
#  '것임',
#  '나',
#  '파견경위',
#  '및',
#  '경과',
#  '09',
#  '12',
#  '한',
#  'UAE관계가',
#  '포괄적',
#  '전략적',
#  '동반자',
#  '관계',
#  '로',
#  '격상되고',
#  '군사협력관계도',
#  '강화',
#  '10',
#  '2',
#  'UAE군',
#  '총참모장',
#  '방한',
#  '시',
#  '군사협력',
#  '방안을',
#  '폭넓게',
#  '논의한',
#  '이후',
#  '군사협력이',
#  '급속히',
#  '발전',
#  '10',
#  '5',
#  'UAE',
#  '국빈',
#  '방한으로',
#  '군사협력',
#  '심화',
#  '확대계기',
#  '마련',
#  '특전사',
#  '방문',
#  '시',
#  '한국',
#  '특전부대의',
#  '우수성을',
#  '매우',
#  '높이',
#  '평가',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '세부협력',
#  '방안',
#  '발전',
#  '요청',
#  '10',
#  '8',
#  '국방장관의',
#  'UAE',
#  '방문',
#  '시',
#  'UAE측이',
#  '한국군',
#  '특전부대의',
#  'UAE',
#  '파견과',
#  '긴밀한',
#  '훈련협력을',
#  '우리측에',
#  '요청',
#  '10',
#  '10',
#  '군',
#  '현지',
#  '실사단',
#  '파견',
#  '부대',
#  '파견',
#  '여건',
#  '확인',
#  '점검',
#  '10',
#  '11',
#  '외교부',
#  '기획재정부',
#  '등과',
#  '부대',
#  '파견계획',
#  '협조',
#  '완료',
#  '10',
#  '11',
#  '9',
#  '국무회의',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육',
#  '훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '심의',
#  '의결',
#  '5',
#  '2',
#  '기본',
#  '계획',
#  '6',
#  '가',
#  '파견부대',
#  '규모',
#  '150명',
#  '이내',
#  '1진',
#  '130명',
#  '특전사',
#  '위주',
#  '특수전',
#  '교육훈련',
#  '지원',
#  '및',
#  '연합훈련을',
#  '위한',
#  '최소규모의',
#  '단위부대',
#  '편성',
#  '나',
#  '파견',
#  '지역',
#  'UAE',
#  '아부다비주',
#  '알',
#  '아인',
#  '소재',
#  '특수전',
#  '학교',
#  '다',
#  '임',
#  '무',
#  'UAE군',
#  '특수전',
#  '부대에',
#  '대한',
#  '교육훈련',
#  '지원',
#  'UAE군',
#  '특수전',
#  '부대와의',
#  '연합훈련',
#  '및',
#  '연습',
#  '유사시',
#  '우리',
#  '국민',
#  '보호',
#  '라',
#  '파견',
#  '기간',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '필요시',
#  '협조장교',
#  '및',
#  '선발대',
#  '인원은',
#  '사전에',
#  '파견',
#  '마',
#  '부대',
#  '교대',
#  '4',
#  '6개월',
#  '주기로',
#  '현지에서',
#  '임무교대',
#  '바',
#  '파견부대',
#  '지휘',
#  '부대',
#  '지휘권은',
#  '한국군이',
#  '보유',
#  '합동참모의장이',
#  '작전',
#  '지휘',
#  '육본',
#  '및',
#  '특전사에서',
#  '전투근무지원',
#  '및',
#  '교육훈련',
#  '지도감독',
#  '사',
#  '부대파견',
#  '및',
#  '임무수행',
#  '경비는',
#  '우리',
#  '정부가',
#  '부담',
#  '부대',
#  '주둔',
#  '시설',
#  '훈련장',
#  '등은',
#  'UAE',
#  '측에서',
#  '제공',
#  '3',
#  '예산',
#  '소요',
#  '가',
#  '11년도',
#  '소요예산',
#  '약',
#  '137억원',
#  '나',
#  '예산조치',
#  '국회',
#  '동의',
#  '후',
#  '2011년도',
#  '예산안에',
#  '대한',
#  '국회',
#  '심의',
#  '과정에서',
#  '반영',
#  '추진',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '비용추계서',
#  '1',
#  '비용추계',
#  '요약',
#  '가',
#  '재정수반요인',
#  '부대의',
#  '파견경비는',
#  '우리',
#  '정부의',
#  '부담으로',
#  '함',
#  '나',
#  '비용추계의',
#  '전제',
#  '국군부대의',
#  'UAE',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '파견',
#  '연장',
#  '기간',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '파견부대',
#  '규모',
#  '150명',
#  '이내',
#  '다',
#  '비용추계의',
#  '결과',
#  '연',
#  '도',
#  '구',
#  '분',
#  '인',
#  '건',
#  '비',
#  '운',
#  '영',
#  '비',
#  '소',
#  '계',
#  'a',
#  '소',
#  '계',
#  'b',
#  '지',
#  '출',
#  '수',
#  '입',
#  '2011',
#  '2',
#  '398',
#  '11',
#  '312',
#  '13',
#  '710',
#  '2012',
#  '2',
#  '398',
#  '5',
#  '383',
#  '7',
#  '781',
#  '단위',
#  '백만원',
#  '합',
#  '계',
#  '4',
#  '796',
#  '16',
#  '695',
#  '21',
#  '491',
#  '총',
#  '비용',
#  'a',
#  'b',
#  '13',
#  '710',
#  '7',
#  '781',
#  '21',
#  '491',
#  '라',
#  '부대의견',
#  '없음',
#  '마',
#  '작성자',
#  '작성자',
#  '이름',
#  '국방부',
#  '국제평화협력과장',
#  '대령',
#  '유재익',
#  '연락처',
#  '02',
#  '748',
#  '6350',
#  '7',
#  '8',
#  '2',
#  '비용추계의',
#  '상세내역',
#  '가',
#  '지',
#  '출',
#  '부대',
#  '운영',
#  '유지',
#  '비용',
#  '21',
#  '491백만원',
#  '단위',
#  '백만원',
#  '구',
#  '분',
#  '계',
#  '해외파견근무수당',
#  '증',
#  '식',
#  '피',
#  '복',
#  '비',
#  '수',
#  '송',
#  '비',
#  '장비',
#  '물자',
#  '획득',
#  '유지비',
#  '기타',
#  '부대',
#  '운영비',
#  '2011',
#  '13',
#  '710',
#  '2',
#  '398',
#  '1',
#  '335',
#  '1',
#  '772',
#  '6',
#  '074',
#  '2',
#  '131',
#  '나',
#  '수',
#  '입',
#  '2012',
#  '7',
#  '781',
#  '2',
#  '398',
#  '1',
#  '315',
#  '1',
#  '072',
#  '913',
#  '2',
#  '083',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '재원조달계획서',
#  '1',
#  '부문별',
#  '재원분담계획',
#  '단위',
#  '백만원',
#  '연',
#  '도',
#  '구',
#  '분',
#  '중앙정부',
#  '일반회계',
#  '예',
#  '비',
#  '비',
#  '지방자치단계',
#  '그',
#  '밖의',
#  '공공단체',
#  '민',
#  '간',
#  '합',
#  '계',
#  '2011',
#  '13',
#  '710',
#  '13',
#  '710',
#  '2012이후',
#  '합',
#  '계',
#  '7',
#  '781',
#  '7',
#  '781',
#  '21',
#  '491',
#  '21',
#  '491',
#  '13',
#  '710',
#  '7',
#  '781',
#  '21',
#  '491',
#  '2',
#  '재원조달의',
#  '구체적인',
#  '방안',
#  '국군부대의',
#  'UAE군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안에',
#  '따른',
#  '소요예산은',
#  '2011년도',
#  '정부예산에서',
#  '137억원을',
#  '지출할',
#  '예정임',
#  '3',
#  '부대의견',
#  '없음',
#  '4',
#  '협의사항',
#  '국회동의',
#  '결과에',
#  '따라',
#  '기획재정부와',
#  '협의함',
#  '5',
#  '작성자',
#  '작성자',
#  '이름',
#  '국방부',
#  '국제평화협력과장',
#  '대령',
#  '유재익',
#  '연락처',
#  '02',
#  '748',
#  '6350',
#  '9',
#  '10',
#  '의안',
#  '소관',
#  '부서명',
#  '국방부',
#  '국방정책',
#  '실',
#  '국제평화협력',
#  '과',
#  '연',
#  '락',
#  '처',
#  '02',
#  '748',
#  '6350']

# %%
tokens_ko[:10]
# Out:
# ['국군부대의', '아랍에미리트', 'UAE', '군', '교육훈련', '지원', '등에', '관한', '파견', '동의안']

# %%
ko = nltk.Text(tokens_ko, name='대한민국 국회 의안 제 1809897호')
ko
# Out:
# <Text: 대한민국 국회 의안 제 1809897호>

# %%
type(ko)
# Out:
# nltk.text.Text

# %%
ko.tokens
# Out:
# ['국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '의안',
#  '제출연월일',
#  '2010',
#  '11',
#  '15',
#  '9897',
#  '번호',
#  '제',
#  '출',
#  '자',
#  '정',
#  '부',
#  '제안이유',
#  '가',
#  'UAE측',
#  '요청과',
#  '협의에',
#  '따라',
#  '국익창출과',
#  '다양한',
#  '지역에서의',
#  '우리',
#  '특전부대',
#  '임무수행능력',
#  '향상',
#  '등을',
#  '목적으로',
#  '국군부대를',
#  'UAE에',
#  '파견하려는',
#  '것임',
#  '나',
#  '국군부대',
#  '파견을',
#  '계기로',
#  '우리',
#  '특전부대의',
#  '전투력',
#  '향상은',
#  '물론',
#  'UAE에',
#  '대한',
#  '방산수출협력',
#  '확대',
#  '국방운영체계',
#  '수출',
#  '예비역',
#  '및',
#  '민간',
#  '전문인력',
#  '진출',
#  '양국간',
#  '경제협력',
#  '확대',
#  '등이',
#  '기대됨',
#  '주요내용',
#  '가',
#  '국군부대의',
#  '임무는',
#  'UAE군',
#  '특수전',
#  '부대에',
#  '대한',
#  '교육훈련',
#  '지원',
#  'UAE군',
#  '특수전',
#  '부대와',
#  '연합훈련',
#  '및',
#  '연습',
#  '유사시',
#  '우리',
#  '국민',
#  '보호임',
#  '나',
#  '파견규모는',
#  '150명',
#  '이내이며',
#  '파견지역은',
#  'UAE',
#  '아부다비주',
#  '알아인',
#  '소재',
#  '특수전학교임',
#  '다',
#  '파견기간은',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지임',
#  '라',
#  '부대',
#  '지휘권은',
#  '한국군이',
#  '보유하며',
#  '우리',
#  '합동참모의장이',
#  '작전지휘함',
#  '마',
#  '국군부대의',
#  '파견경비는',
#  '우리',
#  '정부의',
#  '부담으로',
#  '함',
#  '참고사항',
#  '가',
#  '관련법령',
#  '헌법',
#  '제60조',
#  '제2항',
#  '나',
#  '예산조치',
#  '국회',
#  '동의',
#  '후',
#  '2011년도',
#  '예산안에',
#  '대한',
#  '국회',
#  '심의과정',
#  '에서',
#  '반영',
#  '추진',
#  '다',
#  '합',
#  '의',
#  '외교통상부',
#  '기획재정부와',
#  '합의되었음',
#  '1',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  'UAE군',
#  '교육훈련',
#  '지원',
#  '등을',
#  '위해',
#  '150명',
#  '이내의',
#  '국군부대를',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '2년간',
#  'UAE에',
#  '파견하는',
#  '것을',
#  '헌법',
#  '제60조',
#  '제2항의',
#  '규정에',
#  '따라',
#  '동의한다',
#  '3',
#  '1',
#  '국군부대',
#  '파견',
#  '목적',
#  '및',
#  '경과',
#  '가',
#  '파견목적',
#  'UAE측',
#  '요청과',
#  '협의에',
#  '따라',
#  '국익창출과',
#  '다양한',
#  '지역에서의',
#  '우리',
#  '특전부대',
#  '임무수행능력',
#  '향상',
#  '등을',
#  '목적으로',
#  '국군부대를',
#  'UAE에',
#  '파견하려는',
#  '것임',
#  '나',
#  '파견경위',
#  '및',
#  '경과',
#  '09',
#  '12',
#  '한',
#  'UAE관계가',
#  '포괄적',
#  '전략적',
#  '동반자',
#  '관계',
#  '로',
#  '격상되고',
#  '군사협력관계도',
#  '강화',
#  '10',
#  '2',
#  'UAE군',
#  '총참모장',
#  '방한',
#  '시',
#  '군사협력',
#  '방안을',
#  '폭넓게',
#  '논의한',
#  '이후',
#  '군사협력이',
#  '급속히',
#  '발전',
#  '10',
#  '5',
#  'UAE',
#  '국빈',
#  '방한으로',
#  '군사협력',
#  '심화',
#  '확대계기',
#  '마련',
#  '특전사',
#  '방문',
#  '시',
#  '한국',
#  '특전부대의',
#  '우수성을',
#  '매우',
#  '높이',
#  '평가',
#  '교육',
#  '훈련',
#  '지원',
#  '등',
#  '세부협력',
#  '방안',
#  '발전',
#  '요청',
#  '10',
#  '8',
#  '국방장관의',
#  'UAE',
#  '방문',
#  '시',
#  'UAE측이',
#  '한국군',
#  '특전부대의',
#  'UAE',
#  '파견과',
#  '긴밀한',
#  '훈련협력을',
#  '우리측에',
#  '요청',
#  '10',
#  '10',
#  '군',
#  '현지',
#  '실사단',
#  '파견',
#  '부대',
#  '파견',
#  '여건',
#  '확인',
#  '점검',
#  '10',
#  '11',
#  '외교부',
#  '기획재정부',
#  '등과',
#  '부대',
#  '파견계획',
#  '협조',
#  '완료',
#  '10',
#  '11',
#  '9',
#  '국무회의',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육',
#  '훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '심의',
#  '의결',
#  '5',
#  '2',
#  '기본',
#  '계획',
#  '6',
#  '가',
#  '파견부대',
#  '규모',
#  '150명',
#  '이내',
#  '1진',
#  '130명',
#  '특전사',
#  '위주',
#  '특수전',
#  '교육훈련',
#  '지원',
#  '및',
#  '연합훈련을',
#  '위한',
#  '최소규모의',
#  '단위부대',
#  '편성',
#  '나',
#  '파견',
#  '지역',
#  'UAE',
#  '아부다비주',
#  '알',
#  '아인',
#  '소재',
#  '특수전',
#  '학교',
#  '다',
#  '임',
#  '무',
#  'UAE군',
#  '특수전',
#  '부대에',
#  '대한',
#  '교육훈련',
#  '지원',
#  'UAE군',
#  '특수전',
#  '부대와의',
#  '연합훈련',
#  '및',
#  '연습',
#  '유사시',
#  '우리',
#  '국민',
#  '보호',
#  '라',
#  '파견',
#  '기간',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '필요시',
#  '협조장교',
#  '및',
#  '선발대',
#  '인원은',
#  '사전에',
#  '파견',
#  '마',
#  '부대',
#  '교대',
#  '4',
#  '6개월',
#  '주기로',
#  '현지에서',
#  '임무교대',
#  '바',
#  '파견부대',
#  '지휘',
#  '부대',
#  '지휘권은',
#  '한국군이',
#  '보유',
#  '합동참모의장이',
#  '작전',
#  '지휘',
#  '육본',
#  '및',
#  '특전사에서',
#  '전투근무지원',
#  '및',
#  '교육훈련',
#  '지도감독',
#  '사',
#  '부대파견',
#  '및',
#  '임무수행',
#  '경비는',
#  '우리',
#  '정부가',
#  '부담',
#  '부대',
#  '주둔',
#  '시설',
#  '훈련장',
#  '등은',
#  'UAE',
#  '측에서',
#  '제공',
#  '3',
#  '예산',
#  '소요',
#  '가',
#  '11년도',
#  '소요예산',
#  '약',
#  '137억원',
#  '나',
#  '예산조치',
#  '국회',
#  '동의',
#  '후',
#  '2011년도',
#  '예산안에',
#  '대한',
#  '국회',
#  '심의',
#  '과정에서',
#  '반영',
#  '추진',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '비용추계서',
#  '1',
#  '비용추계',
#  '요약',
#  '가',
#  '재정수반요인',
#  '부대의',
#  '파견경비는',
#  '우리',
#  '정부의',
#  '부담으로',
#  '함',
#  '나',
#  '비용추계의',
#  '전제',
#  '국군부대의',
#  'UAE',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '파견',
#  '연장',
#  '기간',
#  '2011년',
#  '1월',
#  '1일부터',
#  '2012년',
#  '12월',
#  '31일까지',
#  '파견부대',
#  '규모',
#  '150명',
#  '이내',
#  '다',
#  '비용추계의',
#  '결과',
#  '연',
#  '도',
#  '구',
#  '분',
#  '인',
#  '건',
#  '비',
#  '운',
#  '영',
#  '비',
#  '소',
#  '계',
#  'a',
#  '소',
#  '계',
#  'b',
#  '지',
#  '출',
#  '수',
#  '입',
#  '2011',
#  '2',
#  '398',
#  '11',
#  '312',
#  '13',
#  '710',
#  '2012',
#  '2',
#  '398',
#  '5',
#  '383',
#  '7',
#  '781',
#  '단위',
#  '백만원',
#  '합',
#  '계',
#  '4',
#  '796',
#  '16',
#  '695',
#  '21',
#  '491',
#  '총',
#  '비용',
#  'a',
#  'b',
#  '13',
#  '710',
#  '7',
#  '781',
#  '21',
#  '491',
#  '라',
#  '부대의견',
#  '없음',
#  '마',
#  '작성자',
#  '작성자',
#  '이름',
#  '국방부',
#  '국제평화협력과장',
#  '대령',
#  '유재익',
#  '연락처',
#  '02',
#  '748',
#  '6350',
#  '7',
#  '8',
#  '2',
#  '비용추계의',
#  '상세내역',
#  '가',
#  '지',
#  '출',
#  '부대',
#  '운영',
#  '유지',
#  '비용',
#  '21',
#  '491백만원',
#  '단위',
#  '백만원',
#  '구',
#  '분',
#  '계',
#  '해외파견근무수당',
#  '증',
#  '식',
#  '피',
#  '복',
#  '비',
#  '수',
#  '송',
#  '비',
#  '장비',
#  '물자',
#  '획득',
#  '유지비',
#  '기타',
#  '부대',
#  '운영비',
#  '2011',
#  '13',
#  '710',
#  '2',
#  '398',
#  '1',
#  '335',
#  '1',
#  '772',
#  '6',
#  '074',
#  '2',
#  '131',
#  '나',
#  '수',
#  '입',
#  '2012',
#  '7',
#  '781',
#  '2',
#  '398',
#  '1',
#  '315',
#  '1',
#  '072',
#  '913',
#  '2',
#  '083',
#  '국군부대의',
#  '아랍에미리트',
#  'UAE',
#  '군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안',
#  '재원조달계획서',
#  '1',
#  '부문별',
#  '재원분담계획',
#  '단위',
#  '백만원',
#  '연',
#  '도',
#  '구',
#  '분',
#  '중앙정부',
#  '일반회계',
#  '예',
#  '비',
#  '비',
#  '지방자치단계',
#  '그',
#  '밖의',
#  '공공단체',
#  '민',
#  '간',
#  '합',
#  '계',
#  '2011',
#  '13',
#  '710',
#  '13',
#  '710',
#  '2012이후',
#  '합',
#  '계',
#  '7',
#  '781',
#  '7',
#  '781',
#  '21',
#  '491',
#  '21',
#  '491',
#  '13',
#  '710',
#  '7',
#  '781',
#  '21',
#  '491',
#  '2',
#  '재원조달의',
#  '구체적인',
#  '방안',
#  '국군부대의',
#  'UAE군',
#  '교육훈련',
#  '지원',
#  '등에',
#  '관한',
#  '파견',
#  '동의안에',
#  '따른',
#  '소요예산은',
#  '2011년도',
#  '정부예산에서',
#  '137억원을',
#  '지출할',
#  '예정임',
#  '3',
#  '부대의견',
#  '없음',
#  '4',
#  '협의사항',
#  '국회동의',
#  '결과에',
#  '따라',
#  '기획재정부와',
#  '협의함',
#  '5',
#  '작성자',
#  '작성자',
#  '이름',
#  '국방부',
#  '국제평화협력과장',
#  '대령',
#  '유재익',
#  '연락처',
#  '02',
#  '748',
#  '6350',
#  '9',
#  '10',
#  '의안',
#  '소관',
#  '부서명',
#  '국방부',
#  '국방정책',
#  '실',
#  '국제평화협력',
#  '과',
#  '연',
#  '락',
#  '처',
#  '02',
#  '748',
#  '6350']

# %% [markdown]
# #### 빈도분포 `.vocab()`
#
# `.vocab()` 은 토큰의 **빈도분포(frequency distribution)**를 반환해 준다.

# %%
ko.vocab()
# Out:
# FreqDist({'파견': 14, 'UAE': 12, '지원': 12, '교육훈련': 11, '및': 10, '2': 10, '국군부대의': 9, '우리': 9, '가': 8, '나': 8, ...})

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm

plt.rcParams['axes.grid']=True
plt.rcParams['figure.figsize']=(14,4)
import seaborn as sns 

font_path='C:/Windows/Fonts/Malgun.ttf'
fontname=fm.FontProperties(fname=font_path, size=18).get_name()

plt.rcParams['font.family']=fontname
plt.rcParams['axes.unicode_minus']=False
plt.title('한글 테스트')

plt.figure(figsize=(12,6))
ko.plot(50)
plt.show()

# %% [markdown]
# 필터링...

# %% [markdown]
# 단어와 일치하는 토큰수..

# %%
ko.count('교육')
# Out:
# 2

# %%
ko.count('지원')
# Out:
# 12

# %% [markdown]
# 분산(Dispersion) 플롯

# %%
plt.figure(figsize=(12,6))
ko.dispersion_plot([ 'UAE', '군', '교육훈련', '지원' ])

# %% [markdown]
# #### 일치(Concordance)
#
# 토큰에서 일치하는 부분을 출력한다.

# %%
ko.concordance('UAE', lines=5)

# %% [markdown]
# ### 유사 단어 찾기
#
# [text.Text.similar()](https://www.nltk.org/api/nltk.html?highlight=nltk%20text#nltk.text.Text.similar)는 분포 유사성에 따라 단어를 찾는다.

# %%
ko.similar('부대')

# %% [markdown]
# ---
#
# ## 요약
#
# * KoNLPy 코퍼스
# * 한글 형태소 분석
# * 한글 단어 토큰
# * NLTK Text
# * PoS Tagging

# %% [markdown]
# # 빈도 분석 응용

# %% [markdown]
# ## 영문 빈도분석

# %%
mydoc = None
with open('data/트럼프취임연설문.txt', 'r', encoding='euc-kr') as f:
# with open(path, 'r', encoding='cp949') as f:
    mydoc = f.read()
    
mydoc[:100]

# %%
tokenizer = RegexpTokenizer('[\w]+')

# %%
words = mydoc.lower()
tokens = tokenizer.tokenize(words)

# %% [markdown]
# ### NLTK 영문 불용어

# %%
stop_words = stopwords.words('english')

# %%
stopped_tokens = [word for word in list(tokens) if not word in stop_words]
stopped_tokens2 = [word for word in stopped_tokens if len(word) > 1]

# %% [markdown]
# ### pandas 이용 빈도

# %%
import pandas as pd
myseries = pd.Series(stopped_tokens2).value_counts()
myseries.head(10)

# %%
mydic = dict(myseries)

# %%
mydic

# %%
import matplotlib.pyplot as 
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color="white", random_state=0)
plt.figure(figsize=(12,8))
plt.imshow(wc.generate_from_frequencies(dict(myseries[:50])))
plt.axis("off")
plt.show()

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# ## 한글 빈도분석

# %%
path = 'data/문재인대통령취임연설문.txt'
mydoc = None
with open(path, 'r', encoding='euckr') as f:
    mydoc = f.read()
    
mydoc[:100]

# %% [markdown]
# ## 한글 불용어
#
#
# 한국어 같은 경우는 토큰화 단계에서 조사나, 접속사를 제거하면 됨으로 따로 정해진 불용어가 없다.
#
# 필요없는 명사나 형용사를 제거하고자 할 때 아래 코드와 같이 직접 불용어 리스트를 정의한 다음 한국어 불용어를 제거한다.

# %%
# 샘플
words = ['소설', '시', '인문', '역사', '예술', '종교', '사회', '과학','경제 경영', '자기계발', '만화', '여행', '잡지',
        '어린이', '청소년','유아', '요리','육아', '가정 살림', '건강 취미', '대학교재','국어와 외국어', 'IT 모바일',
        '수험서 자격증', '초등참고서', '중고등참고서']   #yes24.com의 Category

# %%
stopwords = ['유아', '청소년', '어린이', '육아', '성인', '19금']

# %%
[word for word in words if word not in stopwords]

# %% [markdown]
# ### 불용어 파일 사용
#
#  - ex: https://www.ranks.nl/stopwords/korean

# %%
ko_text = open('data/눈의여왕.txt', encoding='utf-8').read()
ko_stops = open('data/한글불용샘플.txt', encoding='utf-8').read()

# %%
ko_text

# %%
word_tokens = nltk.word_tokenize(ko_text)
stop_words = ko_stops.split(' ')

# %%
# ko_list = [] 
# for w in word_tokens: 
#     if w not in stop_words: 
#         ko_list.append(w)

# %%
len(word_tokens)

# %%
# 불용어 제거
ko_tokens = [each_word for each_word in word_tokens if each_word not in stop_words]

# %%
len(ko_tokens)

# %%
ko_tokens = [word for word in ko_tokens if len(word) > 1]   #1글자 제외

# %%
len(ko_tokens)

# %%
wc = WordCloud(font_path= "C:/Windows/Fonts/NanumGothic.ttf",
               background_color='white', max_words=2000,
              stopwords = stop_words)
# wc = wc.generate(ko_list) # array-like
wc = wc.generate(str(ko_tokens))
wc.words_

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### nltk.Text 이용

# %%
ko_nouns = Okt().nouns(ko_text)

# %%
len(ko_nouns)

# %%
# 불용어 제거
ko_tokens = [word for word in ko_nouns if word not in stop_words]

# %%
len(ko_tokens)

# %%
ko_tokens = [word for word in ko_tokens if len(word) > 1]   #1글자 제외

# %%
len(ko_tokens)

# %%
# nltk.Text 이용
import nltk
kotext = nltk.Text(ko_nouns)

# %%
kodic = kotext.vocab().most_common(100)

# %%
# font_path = '~/Library/Fonts/NanumGothic.otf'
font_path= "C:/Windows/Fonts/NanumGothic.ttf"

wordcloud = WordCloud(font_path=font_path,
                      relative_scaling = 0.2,
                      background_color='white')

wordcloud = wordcloud.generate_from_frequencies(dict(kodic))
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Naver 뉴스검색 빈도분석

# %%
import requests
from bs4 import BeautifulSoup

# url = 'https://search.naver.com/search.naver?query=삼성전자'
url = 'https://search.naver.com/search.naver?where=news&query=삼성전자'
headers = {'user-agent': 'Mozilla/5.0'}
r = requests.get(url, headers=headers)
soup = BeautifulSoup(r.text)
[s.extract() for s in soup('script')]

# %% [markdown]
# ### pandas 이용 빈도분석

# %%
from konlpy.tag import Okt, Kkma

news_nouns = Kkma().nouns(soup.text)
news_nouns[:20]

# %%
news_nouns = Okt().nouns(soup.text)
news_nouns[:20]

# %%
# 불용어 제거
news_tokens = [word for word in news_nouns if word not in stop_words]

# %%
len(news_tokens)

# %%
news_tokens = [word for word in news_tokens if len(word) > 1]   #1글자 제외

# %%
len(news_tokens)

# %%
import pandas as pd
dataseries = pd.Series(news_nouns).value_counts()
dataseries.head(10)

# %%
# font_path = '~/Library/Fonts/NanumGothic.otf'
font_path= "C:/Windows/Fonts/NanumGothic.ttf"

wordcloud = WordCloud(font_path=font_path,
                      relative_scaling = 0.2,
                      background_color='white')

wordcloud = wordcloud.generate_from_frequencies(dict(dataseries[:50]))

plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import requests
from bs4 import BeautifulSoup

# %%
req = requests.get('https://finance.naver.com/sise/sise_index.naver?code=KOSPI')
req.text
soup = BeautifulSoup(req.text, 'html.parser')
print(soup)

# span_list = soup.find('div').find_all('a href')

# soup = BS4()
span_list = soup.find_all('span',class_='tit')
#    lst_100 = soup.find_all('tr',class_='lst100')
#    lst = [lst_50,lst_100]
#    lst_song = []



print(span_list)
# Out:
# <script type="text/javascript">
# function mainSiseMove(code) {
# 	if (code=='KONEX') {
# 		document.location.href='/sise/konex.naver';
# 	} else if(code=='ETF') {
# 		document.location.href='/sise/etf.naver';
#     } else if(code=='ETN') {
#         document.location.href='/sise/etn.naver';
# 	} else {
# 		document.location.href='/sise/sise_index.naver?code='+code;
# 	}
# }
# </script>
# <!--  global include -->
# <html lang="ko">
# <head>
# <title>코스피 : 네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버 금융" name="apple-mobile-web-app-title">
# <meta content="http://finance.naver.com/sise/sise_index.naver" property="og:url">
# <meta content="코스피 : 네이버 금융" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# ...

# %%
span_list2 = []

for span in span_list:
    span_list2.append(span.text)
    
# print(span_list2)

# del span_list2[0]

# print(span_list2)

span_list3 = []

for sapn in span_list2:
    if len(span) > 20:
        span_list3.append(span)
        
# print(span_list3)

f = open('.\stock_data1.txt', 'w', encoding='utf-8')
for span in span_list2:
    f.write(span+'\n')

f.close()

# f2 = open('.\stock_data1.txt', 'r', encoding='utf-8')

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 9611-CBA9
#
#  C:\Users\USER\users\sbauser 디렉터리
#
# 2022-12-01  오후 06:11    <DIR>          .
# 2022-12-01  오후 06:11    <DIR>          ..
# 2022-12-01  오후 05:35    <DIR>          .ipynb_checkpoints
# 2022-11-29  오후 04:51         1,054,993 01. Basic of Python, Pandas and Matplotlib  via analysis of CCTV in Seoul.ipynb
# 2022-12-01  오전 10:00            19,968 01. population_in_Seoul.xls
# 2022-11-24  오전 09:53            16,570 1-03Basic2.ipynb
# 2022-12-01  오전 10:00            13,538 1-05Comprehensions.ipynb.txt
# 2022-11-24  오전 11:21            18,900 1123_practice.ipynb
# 2022-11-22  오후 06:28            25,707 20221122이민상.ipynb
# 2022-11-29  오후 03:27            68,113 2-Pandas_외부자료.ipynb
# 2022-12-01  오전 10:00           287,354 2-Pandas-연습_튜토리얼_19Q.ipynb
# 2022-12-01  오전 10:00           135,210 2-Pandas-연습_튜토리얼_20Q_43.ipynb.ipynb
# 2022-12-01  오전 10:59           593,193 2-Pandas-연습-시각화matplot-20Q.ipynb
# ...

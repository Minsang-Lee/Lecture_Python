# %%
f=open('C:\\Users\\USER\\Desktop\\users\\sbuser\\buy_list.txt', 'r', encoding='utf-8')

# %%
lines = f.readlines()
lines
# Out:
# []

# %%
for line in lines:
    print(line)

# %%
f=open('C:\\Users\\USER\\Desktop\\users\\sbuser\\buy_list.txt', 'wt', encoding='utf-8')

# %%
f.write('삼성전자\n')
# Out:
# 5

# %%
f.write('sk하이닉스\n')
# Out:
# 7

# %%
f.close()

# %%
f=open('C:\\Users\\USER\\Desktop\\users\\sbuser\\buy_list.txt', 'r', encoding='utf-8')

# %%
lines = f.readlines()
lines
# Out:
# ['삼성전자\n', 'sk하이닉스\n']

# %%
f.close()

# %%
f=open('C:\\Users\\USER\\Desktop\\users\\sbuser\\number.txt', 'wt', encoding='utf-8')

# %%
f.write('12345678910\n')
# Out:
# 12

# %%
f.close()

# %%
f=open('C:\\Users\\USER\\Desktop\\users\\sbuser\\number.txt', 'r', encoding='utf-8')

# %%
lines = f.readlines()
lines
# Out:
# ['12345678910\n']

# %%
import datetime

# %%
from bs4 import BeautifulSoup

# %%
import urllib.request

# %%
now = datetime.datetime.now()

# %%
nowDate = now.strftime('%Y년 %m월 %d일 %H시 %M분 입니다.')

# %%
print('\n *** python webcrawling project 1 *** \n')
print(' 환영합니다. ' + nowDate)
print(' 오늘의 주요 정보를 요약해 드리겠습니다.\n')
# Out:
#  *** python webcrawling project 1 ***
#
#  환영합니다. 2022년 11월 22일 14시 35분 입니다.
#  오늘의 주요 정보를 요약해 드리겠습니다.

# %%
webpage =urllib.request.urlopen('https://search.naver.com/search.naver?where=nexearch&sm=top_sug.pre&fbm=1&acr=1&acq=%EB%82%A0%EC%94%A8%EC%98%88&qdt=0&ie=utf8&query=%EB%82%A0%EC%94%A8%EC%98%88%EB%B3%B4')
soup=BeautifulSoup(webpage, 'html.parser')
temps=soup.find('div', attrs={'class':'temperature_info'})

print('---> 서울날씨 : ', temps.get_text())
# Out:
# ---> 서울날씨 :   어제보다 1.6° 낮아요  흐림   체감 13.4° 습도 40% 바람(북동풍) 2.1m/s

# %%
webpage =urllib.request.urlopen('https://finance.naver.com/')
soup1=BeautifulSoup(webpage, 'html.parser')
temps1=soup1.find('div', attrs={'class':'section_sise_top'})

print('증권상위 순위 ', temps1.get_text())
# Out:
# 증권상위 순위
# TOP 종목
#
# 거래상위
# 상승
# 하락
# 시가총액 상위
#
#
#
#
#            거래상위 TOP 종목
#            종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.
#
#
#
#
#
#
#
# 종목명
# 현재가
# 전일대비
# 등락률
#
#
#
#
# KODEX 200선물인버스2X
# 3,090
# 상승 40
#   +1.31%
#
#
# 스킨앤스킨
# 287
# 상승 11
#   +3.99%
#
#
# 삼성 인버스 2X WTI원유 선물 ETN
# 140
# 보합
#   0.00%
#
#
# 모아데이타
# 2,845
# 보합
#   0.00%
#
#
# 남선알미늄
# 2,460
# 상승 175
#   +7.66%
#
#
# 동방
# 3,015
# 상승 555
#   +22.56%
#
#
# 베트남개발1
# 276
# 하락 5
#   -1.78%
#
#
# KH 건설
# 579
# 하락 36
#   -5.85%
#
#
# 폴라리스우노
# 1,005
# 상승 55
#   +5.79%
#
#
# 모비데이즈
# 1,250
# 상승 175
#   +16.28%
#
#
# KODEX 코스닥150선물인버스
# 5,330
# 상승 65
#   +1.23%
#
#
# KODEX 레버리지
# 14,420
# 하락 215
#   -1.47%
#
#
# 웰크론한텍
# 5,480
# 상승 170
#   +3.20%
#
#
# 신한 인버스 2X 천연가스 선물 ETN
# 190
# 하락 20
#   -9.52%
#
#
# KODEX 인버스
# 4,900
# 상승 45
#   +0.93%
#
#
#
# 거래상위 더보기
#
#
#
#
#            상승 TOP 종목
#            종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.
#
#
#
#
#
#
#
# 종목명
# 현재가
# 전일대비
# 등락률
#
#
#
#
# 클리노믹스
# 9,450
# 상한가 2,180
#   +29.99%
#
#
# 메리츠화재
# 46,400
# 상한가 10,700
#   +29.97%
#
#
# 에너토크
# 10,500
# 상한가 2,420
#   +29.95%
#
#
# 피코그램
# 16,500
# 상한가 3,800
#   +29.92%
#
#
# 메리츠금융지주
# 34,750
# 상한가 8,000
#   +29.91%
#
#
# 셀피글로벌
# 1,955
# 상한가 450
#   +29.90%
#
#
# 메리츠증권
# 5,870
# 상한가 1,350
#   +29.87%
#
#
# 바이온
# 1,155
# 상한가 265
#   +29.78%
#
#
# 스튜디오산타클로스
# 10,850
# 상한가 2,480
#   +29.63%
#
#
# 금강공업
# 7,600
# 상승 1,420
#   +22.98%
#
#
# 동방
# 3,015
# 상승 555
#   +22.56%
#
#
# 핑거
# 11,500
# 상승 1,760
#   +18.07%
#
#
# 인벤티지랩
# 14,950
# 상승 2,200
#   +17.25%
#
#
# 모비데이즈
# 1,250
# 상승 175
#   +16.28%
#
#
# 코오롱글로벌
# 22,600
# 상승 3,000
#   +15.31%
#
#
#
# 상승 더보기
#
#
#
#
#            하락 TOP 종목
#            종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.
#
#
#
#
#
#
#
# 종목명
# 현재가
# 전일대비
# 등락률
#
#
#
#
# 하이드로리튬
# 23,750
# 하락 -4,600
#   -16.23%
#
#
# 중앙디앤엠
# 673
# 하락 -99
#   -12.82%
#
#
# 케이비제20호스팩
# 1,500
# 하락 -195
#   -11.50%
#
#
# 하나 블룸버그 -2X 천연가스 선물 ETN(H)
# 15,390
# 하락 -1,970
#   -11.35%
#
#
# 삼성 인버스 2X 천연가스 선물 ETN C
# 15,765
# 하락 -2,015
#   -11.33%
#
#
# 미래에셋 S&P -2X 천연가스 선물 ETN(H)
# 15,425
# 하락 -1,970
#   -11.33%
#
#
# 제주항공
# 9,980
# 하락 -1,270
#   -11.29%
#
#
# 신한 블룸버그 -2X 천연가스 선물 ETN(H)
# 15,385
# 하락 -1,945
#   -11.22%
#
#
# 대신 S&P 인버스 2X 천연가스 선물 ETN
# 14,575
# 하락 -1,825
#   -11.13%
#
#
# 메리츠 블룸버그 -2X 천연가스 선물 ETN(H)
# 15,385
# 하락 -1,925
#   -11.12%
#
#
# TRUE 블룸버그 인버스 2X 천연가스선물 ETN
# 14,615
# 하락 -1,810
#   -11.02%
#
#
# 이엠앤아이
# 7,030
# 하락 -850
#   -10.79%
#
#
# QV 블룸버그 -2X 천연가스 선물 ETN(H)
# 15,410
# 하락 -1,830
#   -10.61%
#
#
# KB 블룸버그 인버스2X 천연가스선물 ETN(H)
# 15,455
# 하락 -1,820
#   -10.54%
#
#
# 경동인베스트
# 90,500
# 하락 -10,500
#   -10.40%
#
#
#
# 하락 더보기
#
#
#
#
#            시가총액 상위 TOP 종목
#            종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.
#
#
#
#
#
#
#
#
# 종목명
# 현재가
# 전일대비
# 등락률
#
#
#
#
# 삼성전자
# 60,600
# 하락 800
#   -1.30%
#
#
# LG에너지솔루션
# 571,000
# 하락 2,000
#   -0.35%
#
#
# 삼성바이오로직스
# 888,000
# 보합
#   0.00%
#
#
# SK하이닉스
# 85,200
# 하락 1,100
#   -1.27%
#
#
# LG화학
# 687,000
# 상승 5,000
#   +0.73%
#
#
# 삼성SDI
# 680,000
# 하락 14,000
#   -2.02%
#
#
# 삼성전자우
# 55,300
# 하락 1,100
#   -1.95%
#
#
# 현대차
# 165,500
# 하락 2,500
#   -1.49%
#
#
# NAVER
# 180,500
# 하락 2,000
#   -1.10%
#
#
# 기아
# 65,200
# 보합
#   0.00%
#
#
# 셀트리온
# 176,500
# 하락 500
#   -0.28%
#
#
# POSCO홀딩스
# 292,500
# 상승 4,000
#   +1.39%
#
#
# 카카오
# 54,300
# 하락 2,000
#   -3.55%
#
#
# 삼성물산
# 122,500
# 보합
#   0.00%
#
#
# KB금융
# 49,800
# 상승 100
#   +0.20%
#
#
#
# 시가총액 상위 더보기

# %%
webpage =urllib.request.urlopen('https://finance.naver.com/sise/sise_rise.naver')
soup2=BeautifulSoup(webpage, 'html.parser')
temps2=soup2.find('div', attrs={'class':'snb snb2'})
temps3=soup2.find('ul', attrs={'class':'nav1'})

print('코스피 순위 ', temps2.get_text(), temps3.get_text())
# Out:
# 코스피 순위
# 국내증시
#
# 주요시세정보
#
# 코스피
# 코스닥
# 선물
# 코스피200
# 코넥스
# 시가총액
# 배당
# 업종
# 테마
# 그룹사
# ETF
# ETN
# ª?Ω?
# 보합
# 하락
# 상한가
# 하한가
# 급등
# 급락
# 거래상위
# 급증
# 급감
# 투자자별매매동향
# 외국인매매
# 기관매매
# 프로그램매매동향
# 증시자금동향
# 신규상장
# 외국인보유
# 장외시세
# IPO
#
#
# 투자자보호
#
# 관리종목
# 거래정지종목
# 시장경보종목
#
#
# 종목조건검색
#
# 골든크로스
# 갭상승
# 이격도과열
# 투심과열
# 상대강도과열
#
#
# 기업 전자공시
# 공매도 종합 현황
#
#
# 주요시세정보
#
# 코스피
# 코스닥
# 선물
# 코스피200
# 코넥스
# 시가총액
# 배당
# 업종
# 테마
# 그룹사
# ETF
# ETN
# ª?Ω?
# 보합
# 하락
# 상한가
# 하한가
# 급등
# 급락
# 거래상위
# 급증
# 급감
# 투자자별매매동향
# 외국인매매
# 기관매매
# 프로그램매매동향
# 증시자금동향
# 신규상장
# 외국인보유
# 장외시세
# IPO
#
#
# 투자자보호
#
# 관리종목
# 거래정지종목
# 시장경보종목
#
#
# 종목조건검색
#
# 골든크로스
# 갭상승
# 이격도과열
# 투심과열
# 상대강도과열
#
#
# 기업 전자공시
# 공매도 종합 현황

# %%
list1 = []
list2 = []
webpage =urllib.request.urlopen('https://movie.naver.com/')
soup3=BeautifulSoup(webpage, 'html.parser')
temps4=soup3.find('div', attrs={'class':'running_tab'})
temps5=soup3.find('div', attrs={'class':'detail'})
list1 = temps4.get_text()
list2 = temps5.get_text()
print('영화순위 ', list1, list2)
# Out:
# 영화순위
#
# 박스오피스
# 현재상영작
# 개봉예정작
# 평점순
# 다운로드순
#
#
# 자백
#
# 평점 - 총 10점 중
#
# 8.52
#
#
#
#
# 소지섭의 재발견, 김윤진의 저력, 나나의 가능성 확인한 '자백'
# 첨부터 끝까지 긴장감 넘치는 반전 스릴러...!! 원작 안보고 관람하는 것을 더 추천합니당
# 나나 이번에 다시 봤다.. 다시 봐도 예쁘더라

# %%
webpage =urllib.request.urlopen('https://movie.naver.com/movie/sdb/rank/rmovie.naver')
soup4=BeautifulSoup(webpage, 'html.parser')
temps5=soup4.find('div', attrs={'class':'tit3'})

list3 = temps5.get_text()

for i in range(0, 10):
    print('영화_순위 ', list3)
# Out:
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버
#
# 영화_순위
# 블랙 팬서: 와칸다 포에버

# %%
import sys

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import platform

# %%
# !python -m pip install -U pip

# %%
# !python -m pip install -U matplotlib

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.6.2'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,4,9,20], 'ro')
plt.plot([0, 18, 2, 8])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0., 5., 0.3)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([2, 3, 5, 10, 15]) #y축 2, 3, 5, 10 x축은 기본적 0,1,2,3,4
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4,],[2,3,5,10])
plt.show()

# %%
import matplotlib.pyplot as plt

data_dict = {'data_x':[1,2,3,4,5], 'data_y':[2,3,5,10,8]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [1,4,9,16])
plt.xlabel('X축 갑', labelpad=30)
plt.ylabel('Y축 값', labelpad=30)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [2,3,5,10])
plt.xlabel('x-axis', labelpad=15, fontdict{'family':'serif','color':'b','weight':'bold','size':14})
plt.ylabel('y-axis', labelpad=20, fontdict{'family':'fantasy','color':'deeppink','weight':'normal','size':'xx-large'})
plt.show()
# Out:
#   Cell In [29], line 4
#     plt.xlabel('x-axis', labelpad=15, fontdict{'family':'serif','color':'b','weight':'bold','size':14})
#                                               ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

font1 = {'family':'serif',
         'color':'b',
         'weight':'bold',
         'size':14
        }

font2 = {'family':'fantasy',
         'color':'deeppink',
         'weight':'normal',
         'size':'xx-large'
        }

plt.plot([1,2,3,4],[2,3,5,10], label='Price ($)')
plt.xlabel('x-axis', labelpad=15, fontdict=font1, loc='right')
plt.ylabel('y-axis', labelpad=20, fontdict=font2, loc='top')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot( [1,4,9,16, 20],  'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price (Won)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc=(0.0, 0.0))
# plt.legend(loc=(0.5, 0.5))
plt.legend(loc='lower right') #(0.5, 0.5))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1
plt.legend(loc='best', ncol=1, fontsize=18)    # ncol = 1

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1
plt.legend(loc='best', ncol=2)    # ncol = 2

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=1, fontsize=14, frameon=True, shadow=True) #shdow T or F

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [2,3,5,10])
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.axis([0,5,0,20]) #x, y축 범위

plt.show()
